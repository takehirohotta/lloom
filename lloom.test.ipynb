# %%
import text_lloom.src.text_lloom.workbench as wb
import pandas as pd
import os
from dotenv import load_dotenv
load_dotenv()
from text_lloom.src.text_lloom.llm import OpenAIModel

# %%
def load_and_combine_data(basedir='/home/takeh/public_health/reports/cluster_comments/'):
    """すべてのクラスターのCSVファイルを読み込み、統合したDataFrameを作成"""
    
    cluster_files = [
        'cluster0_comments.csv',
        'cluster1_comments.csv', 
        'cluster2_comments.csv',
        'cluster3_comments.csv',
        'cluster4_comments.csv'
    ]
    
    all_data = []
    
    for i, file_name in enumerate(cluster_files):
        try:
            # フルパスを構築
            full_path = os.path.join(basedir, file_name)
            print(f"読み込み中: {full_path}")
            df = pd.read_csv(full_path)
            
            # 空でないかチェック
            if len(df) == 0:
                print(f"{file_name} は空のファイルです。スキップします。")
                continue
                
            # クラスター番号を追加
            df['cluster'] = f'cluster_{i}'
            df['cluster_id'] = i
            
            # ユニークなIDを作成（累積インデックス）
            df['doc_id'] = df.index + sum(len(data) for data in all_data)
            
            all_data.append(df)
            print(f"✓ {file_name}: {len(df)}件のコメントを読み込み")
            
        except FileNotFoundError:
            print(f"✗ {full_path} が見つかりません。")
        except Exception as e:
            print(f"✗ {file_name} の読み込みエラー: {e}")
    
    # 全データを統合
    if all_data:
        combined_df = pd.concat(all_data, ignore_index=True)
        print(f"\n✓ 統合完了: 合計 {len(combined_df)} 件のコメント")
        print(f"クラスター分布:\n{combined_df['cluster'].value_counts()}")
        return combined_df
    else:
        print("✗ 読み込み可能なデータがありませんでした。")
        return None

# %%
df = load_and_combine_data()
# Out:
# 読み込み中: /home/takeh/public_health/reports/cluster_comments/cluster0_comments.csv
# ✓ cluster0_comments.csv: 398件のコメントを読み込み
# 読み込み中: /home/takeh/public_health/reports/cluster_comments/cluster1_comments.csv
# ✓ cluster1_comments.csv: 4452件のコメントを読み込み
# 読み込み中: /home/takeh/public_health/reports/cluster_comments/cluster2_comments.csv
# ✓ cluster2_comments.csv: 90件のコメントを読み込み
# 読み込み中: /home/takeh/public_health/reports/cluster_comments/cluster3_comments.csv
# ✓ cluster3_comments.csv: 186件のコメントを読み込み
# 読み込み中: /home/takeh/public_health/reports/cluster_comments/cluster4_comments.csv
# ✓ cluster4_comments.csv: 574件のコメントを読み込み
#
# ✓ 統合完了: 合計 5700 件のコメント
# クラスター分布:
# cluster
# cluster_1    4452
# cluster_4     574
# cluster_0     398
# cluster_3     186
# cluster_2      90
# Name: count, dtype: int64

# %%
df
# Out:
#                         UserID  \
# 0     UCaLJHKwN9DbuWmNQlS5vkog
# 1     UCaLJHKwN9DbuWmNQlS5vkog
# 2     UCaLJHKwN9DbuWmNQlS5vkog
# 3     UCaLJHKwN9DbuWmNQlS5vkog
# 4     UCaLJHKwN9DbuWmNQlS5vkog
# ...                        ...
# 5695  UCP2viLKgu1VQezTYEPOpysg
# 5696  UC6jE6ebLoaYPULWKI6_rzNg
# 5697  UCsCbZ2LsnaK_55UE3G5uKJA
# 5698  UCEiBNKydrDSS1EaQAYKjwLg
# 5699  UC6RStXrFgkbYJQfPKopJyrw
#
#                                                comments    cluster  \
# 0                          こんばんは女性若いアラサー患者は子宮かん乳ガン受け人無理  cluster_0
# 1                            こんばんは若い女性は二十歳三十歳四十歳アラサー多くは  cluster_0
# 2                          こんばんは女性患者子宮頚若い二十歳三十歳来れ将来結婚子供  cluster_0
# 3                  私は間近周辺人女性病気婦人淋しいいません職場転職ますおもい子宮けいがんは  cluster_0
# 4                                  こんばんは子宮痙かん女性患者は正しい情報  cluster_0
# ...                                                 ...        ...
# 5695  私は3年前に子宮頚がんの検査を初めて受けて、引っかかり精密検査受けると軽度異形成と診断されま...  cluster_4
# 5696  軽度異形成になったことがあります。\n組織診は組織を採るから痛かったけど\n普通の検査はブラ...  cluster_4
# 5697                                              大袈裟やな  cluster_4
# 5698  私も数年前に検査に引っかかり泣きながら精密検査に行ったことがあります。幸い異形成の初期で1年...  cluster_4
# 5699  私の母も、私が小学生の頃に乳がんになって、抗がん剤とか大変だったのを見てきたので、、なんとも...  cluster_4
#
#       cluster_id  doc_id
# 0              0       0
# 1              0       1
# 2              0       2
# 3              0       3
# 4              0       4
# ...          ...     ...
# 5695           4    5695
# 5696           4    5696
# 5697           4    5697
# 5698           4    5698
# 5699           4    5699
#
# [5700 rows x 5 columns]

# %%
gpt41mini = OpenAIModel(name="gpt-4.1-mini",
api_key=os.environ["OPENAI_API_KEY"])
gpt41nano = OpenAIModel(name="gpt-4.1-nano",
api_key=os.environ["OPENAI_API_KEY"])

l = wb.lloom(
    df=df,
    text_col="comments",
    id_col="doc_id",
    distill_model=gpt41mini, 
    score_model=gpt41nano     
)

# %%
comment_params = {
    "filter_n_quotes": 2,    
    "summ_n_bullets": 2,     
    "synth_n_concepts": 5    
}

# %%
await l.gen(params=comment_params)
# Out:
# Estimated cost: $2.24
# **Please note that this is only an approximate cost estimate**
#
#
# Action required
# Proceed with generation? (y/n):  y
# Distill-filter
# ⠼ LoadingERROR json_load on: {
#     "relevant_quotes": [ "接種しとくかぁ", "（）」 ]
# }
# ✅ Done
#       doc_id                                           comments
# 0          0                                女性若いアラサー患者\n子宮かん乳ガン
# 1          1                       こんばんは\n若い女性は二十歳三十歳四十歳アラサー多くは
# 2          2                                          女性患者\n子宮頚
# 3          3                                    子宮けいがんは\n職場転職ます
# 4          4                                  子宮痙かん\n女性患者は正しい情報
# ...      ...                                                ...
# 5694    5695  私は3年前に子宮頚がんの検査を初めて受けて、引っかかり精密検査受けると軽度異形成と診断されま...
# 5695    5696  軽度異形成になったことがあります。\n普通の検査はブラシで擦るくらいで痛くないと個人的に感じ...
# 5696    5697                                            大袈裟\nやな
# 5697    5698  私も数年前に検査に引っかかり泣きながら精密検査に行ったことがあります。\n幸い異形成の初期で...
# 5698    5699  私の母も、私が小学生の頃に乳がんになって、抗がん剤とか大変だったのを見てきたので、、なんとも...
#
# [5699 rows x 2 columns]
# Distill-summarize
# ✅ Done
#        doc_id                       comments
# 0           0                     若いアラサー女性患者
# 1           0                      子宮と乳がんの診断
# 2           1        Greeting in the evening
# 3           1  Mention of young women’s ages
# 4           2                     女性患者に関する情報
# ...       ...                            ...
# 11396    5697     Casual conversational tone
# 11397    5698                 数年前に検査で異常が見つかる
# 11398    5698                    初期異形成は1年で消失
# 11399    5699                 母が乳がんで抗がん剤治療経験
# 11400    5699                     自分も検診に行く決意
#
# [11401 rows x 2 columns]
# Cluster
# ⠴ Loading
# /home/takeh/lloom/.venv/lib/python3.11/site-packages/numba/np/ufunc/parallel.py:371: NumbaWarning: The TBB threading layer requires TBB version 2021 update 6 or later i.e., TBB_INTERFACE_VERSION >= 12060. Found TBB_INTERFACE_VERSION = 12050. The TBB threading layer is disabled.
#   warnings.warn(problem)
# ⠦ Loading
# /home/takeh/lloom/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# /home/takeh/lloom/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:132: FutureWarning: 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#   warnings.warn(
# ✅ Done
#        doc_id                               comments  cluster_id
# 11368    5683    Planning to get first dose tomorrow          -1
# 11367    5683        Unaware of new 9-valent vaccine          -1
# 10053    5026            Had a cone biopsy procedure          -1
# 10079    5039       Expressing gratitude to Kirichan          -1
# 10089    5044  Could not get vaccinated at that time          -1
# ...       ...                                    ...         ...
# 11397    5698                         数年前に検査で異常が見つかる           1
# 11398    5698                            初期異形成は1年で消失           1
# 11399    5699                         母が乳がんで抗がん剤治療経験           1
# 11400    5699                             自分も検診に行く決意           1
# 0           0                             若いアラサー女性患者           1
#
# [11401 rows x 3 columns]
# Synthesize
# ⠼ LoadingERROR json_load on: The text examples provided are a collection of summaries, each associated with a unique `example_id`. These summaries cover a wide range of topics, including medical conditions, treatments, and societal issues. Here are some patterns and themes that can be identified from the examples:
#
# 1. **Medical Conditions and Treatments**: Many examples discuss various medical conditions, particularly related to cancer (e.g., cervical cancer, breast cancer), and the importance of early detection and regular check-ups. There are mentions of specific diagnostic tests, treatments, and the experiences of patients undergoing these procedures.
#
# 2. **Vaccination and Public Health**: A significant number of examples focus on HPV vaccination, its importance, and the public's perception of it. There are discussions about the benefits and risks associated with vaccines, as well as the societal and governmental roles in promoting vaccination.
#
# 3. **Gender and Health**: Several examples highlight issues related to women's health, including the challenges they face in accessing healthcare and the societal expectations placed on them. There are also mentions of the need for both men and women to be informed about health risks and preventive measures.
#
# 4. **Societal and Ethical Issues**: Some examples touch on broader societal issues, such as the role of media in shaping public perception, the responsibilities of governments and pharmaceutical companies, and ethical considerations in healthcare.
#
# 5. **Personal Experiences and Emotions**: Many examples capture personal stories and emotional responses to health diagnoses, treatments, and outcomes. These narratives often include expressions of fear, hope, gratitude, and the impact of health issues on individuals and their families.
#
# 6. **Public Awareness and Education**: There is a recurring theme of the need for increased public awareness and education about health issues, particularly regarding preventive measures and the importance of regular health screenings.
#
# Overall, the examples reflect a diverse set of concerns and experiences related to health, highlighting the complexity of medical, societal, and personal factors that influence health outcomes and public health policies.
# ✅ Done
#
#
# Input examples: ['Planning to get first dose tomorrow', 'Unaware of new 9-valent vaccine', 'Had a cone biopsy procedure', 'Expressing gratitude to Kirichan', 'Could not get vaccinated at that time', 'Motivated by seeing Kirichan post-surgery', 'Addressing someone named Kirimaru-chan', '感謝の気持ちを伝える', '感謝の気持ちを伝える', 'Thanking Kiri-chan for important information', 'Demanding response from Soka Gakkai members', 'Addressing someone named Soka-kun', 'Person has received the vaccine', 'Vaccine cost became free from April', 'Received cervical cancer vaccine properly', '感謝の気持ちを伝えている', 'Prefer 4-valent or 9-valent vaccine', 'Everyone should get vaccinated', 'Decided to stop second injection after discussion', 'Person seriously watching Japan', 'Reiwa Yamamoto Taro supporters appearing', 'Men with certain conditions should get vaccinated', 'Japanese phrase expressing confusion', 'Inquiry about manufacturers and vaccine details', '3000 people die annually', 'Older child missed, younger child vaccinated', 'Request for free vaccination opportunity', 'Vaccination targets expanded to include men', '母親の出血は年齢の影響', 'Second injection was very painful', '9-valent vaccine covered by insurance since last year', '日本の子宮頸がん死亡者数多い', '円錐切除手術を受けた経験', 'Received vaccine during middle school', 'Got vaccinated while it was free', "Grateful for Terachan's support", 'Hope they get vaccinated this opportunity', 'Considering getting the HPV vaccine', 'Finished receiving the COVID-19 vaccine', 'Is 節操 an outdated term?', 'Meaning of the word 節操', 'Vaccinate both males and females', 'Vaccination not necessary based on infection rate', 'Diagnosed with mild dysplasia last September', "Refers to Ikoka-sama's drama", 'Addressing a teacher or mentor', '母親の出血は年齢の影響', '母親は不正出血の症状があった', '去年高度異形成で円錐切除', 'Regretting that decision', 'Did not get free vaccine', 'Thought vaccine was only for women', 'Diagnosed with mild dysplasia', "Japanese verb 'おろす' usage", 'Appreciation for Manami and Niko', 'Surprised to learn something about Yokohama', 'High cost of self-paid vaccination', 'Cute ポ character', 'Expressing happiness for Manami', 'Arm muscle sore from multiple vaccines', 'Started HPV vaccination this year', 'Missed HPV vaccine during adolescence', '円錐切除の身体的負担', 'High-grade dysplasia cone biopsy was scary', '円錐切除の方法についての質問', 'Encouragement to receive vaccine', 'Men should get vaccinated', '日本は子宮頸がん死亡率が高い', '感謝の気持ちを表現', 'なっちゃん is very cute and energetic', 'Addressing Sakura-chan affectionately', 'Diagnosis was dysplasia', 'HSIL class 3a diagnosis received', '円錐切除について', '円錐切除手術を受けた経験', '高度異形成で円錐切除手術実施', '感謝の気持ちを伝えている', 'Diagnosed with CIN3 and treated', 'Diagnosed with mild dysplasia two years ago', 'ぎーにょちゃん is always busy', 'Received three public vaccinations in high school', 'Wonders if vaccination is still timely', 'Vaccination strongly recommended for young people', 'Fear of intramuscular injection delays shot', 'Glad to remain unvaccinated', 'Injection pain is unpleasant', 'Inquiry about 9-valent vaccine duration', 'Use of cheerful emojis', 'Mild dysplasia requires observation', 'ちゅんママが帰宅を歓迎', 'Emotional reaction with baby emojis', '荒川区議会議員としての応援', '感謝の意を伝える動画配信', '母親の異常な出血と年齢の関係', 'Wishes men would also get vaccinated', 'Relieved to have received the shot', 'Regrets not getting the injection earlier', 'Getting vaccinated first is advantageous', 'Men can also get vaccinated', 'Cannot get vaccine due to limb deformities', 'Wants vaccination but lacks subsidies', 'Mention of teacher Ririka', 'Asking about arm pain after vaccination', '年間3000人が死亡', '年間3000人近くが死亡', 'Vaccination pain similar to COVID shot', 'Get vaccinated before first sexual intercourse', 'Missed vaccination opportunity due to timing', 'Comparison of similar Japanese phrases', 'Had conization surgery for cervical dysplasia', 'Is targeting HPV treatment meaningful?', 'Injections were not very painful', 'Enable free access for both genders', "Addressing someone directly as 'you'", 'Expression of love in Japanese',  ...
# Output concepts:
# 	name: Vaccination Experience
# 	prompt: Does the text describe a personal experience or decision related to vaccination, including receiving, planning, or reflecting on a vaccine?
# 	example_ids: ['5683', '5006']
# 	name: Gratitude Expression
# 	prompt: Does the text express gratitude or appreciation towards someone or something?
# 	example_ids: ['5039', '5019']
# 	name: Medical Diagnosis
# 	prompt: Does the text mention a medical diagnosis, such as dysplasia or cancer, and any related procedures?
# 	example_ids: ['5026', '2576']
# 	name: Vaccination Advocacy
# 	prompt: Does the text advocate for vaccination, suggesting that others should get vaccinated or discussing the benefits of vaccination?
# 	example_ids: ['2427', '2134']
# 	name: Japanese Language Use
# 	prompt: Does the text include Japanese language elements, such as kanji, hiragana, or katakana, or discuss Japanese cultural references?
# 	example_ids: ['2010', '2801']
#
# Input examples: ['Regular test with painless brush method', 'Thanks for sharing difficult topics, Hina', "Missed last year's checkup due pregnancy", 'Concerns about safety of altered schedule', 'Apologizing if preference is biological children', 'Supporting children through donations and fundraising', 'Mention of young women’s ages', 'Anti-vaccine groups are frightening', 'Before resumption', 'We are not guinea pigs', 'Must deeply reflect on actions', 'Mass media committed a grave sin', 'Expressing genuine gratitude', 'Positive attitude after difficult surgery', 'Annual health checkups are very important', 'Inquiry about paying for test personally', 'Effectiveness of test after age 36', 'Request to permanently save information', 'Cannot undergo cervical cancer screening', 'Unable to undergo cervical cancer screening', 'Greeting in the evening', 'Expression of exaggeration', 'Casual conversational tone', "Take care and don't be complacent", 'Glad to see you healthy', 'Planning to go for a medical test', 'Wishing good health', 'Thankful for clear explanation', 'Wishes for physical and mental relief', 'Visited obstetrics and gynecology clinic', 'Use of heart or love emoji', 'Expression of love or affection', 'Sister experienced vomiting from vaccine side effects', 'Surgery scheduled after test results', 'Congratulations on hospital discharge', 'Is vaccine ineffective after prior infection?', 'Implied child was vaccinated', 'Parent recommended vaccination', 'Questioning denial of vaccine-symptom causality', 'No regret in avoiding vaccine due to side effects', 'Suggests relying on nurses in psychiatry', 'Doctors may see it as acting', 'Questioning the reason for vaccination', 'Expressing strong negative feelings', 'Encouraging Kirichan to do her best', 'Experienced same illness and surgery', 'Wishing them to take care', 'It can happen to any woman', "I couldn't talk to anyone", 'Recently gave birth to a healthy baby', 'Wishing for a successful surgery', 'Many want to get tested', 'Increase from 2 to 3 noted', 'Speaker claims invincibility and warns others', 'HPV vaccine critics create vengeful monster', 'Continuous learning is essential in life', 'Consistency and perseverance lead to success', 'Wishing for safe completion', 'Respect for courageous video', 'Expression of strong emotions', 'Encouragement for surgery', 'Encouraging rest and relaxation when possible', 'Cannot engage in certain activities before third dose', 'Surgery appreciation and encouragement', 'Parents should make the decisions', 'Children suffer due to ignorant parents', 'Want experienced people to share', 'Asking if anyone has taken this', 'Expressing strong frustration or insult', '33 victims have been affected', 'Questioning actions if daughter victimized', 'Asking if they understood', 'Victims exceed just 33 people', 'Compliment despite swelling', 'Appreciation for surgery effort', "Didn't know about the balloon inside", 'Woke up surprised by something inside', "It's a dance", 'Even I can do it', 'Wondering if still trembling now', 'Reflecting on an event from 7 years ago', 'Cannot tell parents about hospital visit', 'Severe menstrual pain', 'Still inexperienced but learned a lot', 'Decided to properly take it this year', 'Avoided for years due to embarrassment', 'Expressing hope and good luck', '720件 indicates a large quantity', 'Statement followed by a laughing emoji', 'Doctors ensure their own children receive it', 'ヒス indicates emotional outburst or hysteria', 'Test vaccine side effects on penis', 'Prediction of long-lasting continuation', 'Comparing modern trends to outdated practices', 'Warning against harming unvaccinated individuals', 'HPV vaccine safety questioned aggressively', 'Expresses desire to kill many men', 'Blames men for causing cervical cancer', 'Reference to America in a casual tone', 'HPV vaccine is imported from overseas', 'Blame on men for cervical cancer', 'Challenge to prove vaccine safety personally', 'Expressing feelings of sadness ...
# Output concepts:
# 	name: Health Checkup Encouragement
# 	prompt: Does the text encourage or emphasize the importance of regular health checkups or screenings?
# 	example_ids: ['5009', '1056']
# 	name: Vaccine Concerns
# 	prompt: Does the text express concerns or skepticism about vaccines, particularly related to side effects or effectiveness?
# 	example_ids: ['2383', '501']
# 	name: Expression of Gratitude
# 	prompt: Does the text express gratitude or appreciation for information, support, or actions taken?
# 	example_ids: ['5673', '1053']
# 	name: Surgery and Recovery
# 	prompt: Does the text discuss undergoing surgery, recovery, or related experiences?
# 	example_ids: ['5042', '5063']
# 	name: Emotional Support
# 	prompt: Does the text offer emotional support, encouragement, or well wishes to someone?
# 	example_ids: ['5031', '4483']
#
#
# Review
# ✅ Done
#
#     Auto-review:
#     Removed (2):
#         ['Gratitude Expression', 'Expression of Gratitude']
#     Merged (2):
#     	['Vaccination Experience', 'Vaccination Advocacy'] --> Vaccination Perspectives: Does the text discuss personal experiences or advocacy related to vaccination, including receiving vaccines or promoting their benefits?
# 	['Health Checkup Encouragement', 'Emotional Support'] --> Health and Support: Does the text emphasize the importance of health checkups or offer emotional support and encouragement for health-related matters?
#
#
#
#
# Synthesize 1: (n=6 concepts)
# - Concept 5711b6ed-83b3-45dc-a1c5-4567cd6c903b:
# 	Medical Diagnosis
# 	- Prompt: Does the text mention a medical diagnosis, such as dysplasia or cancer, and any related procedures?
# - Concept 644481e1-85f4-4ccd-91ee-e0170e4872fd:
# 	Japanese Language Use
# 	- Prompt: Does the text include Japanese language elements, such as kanji, hiragana, or katakana, or discuss Japanese cultural references?
# - Concept f919bf45-e306-4c30-a27a-28f74e10a0b2:
# 	Vaccine Concerns
# 	- Prompt: Does the text express concerns or skepticism about vaccines, particularly related to side effects or effectiveness?
# - Concept e44785ea-aacf-464e-8eef-8463c2976c1b:
# 	Surgery and Recovery
# 	- Prompt: Does the text discuss undergoing surgery, recovery, or related experiences?
# - Concept 19bdd75e-e320-436f-80d9-b896844a9f3d:
# 	Vaccination Perspectives
# 	- Prompt: Does the text discuss personal experiences or advocacy related to vaccination, including receiving vaccines or promoting their benefits?
# - Concept 92ab2c05-358b-4fb7-8a69-65b106a057ab:
# 	Health and Support
# 	- Prompt: Does the text emphasize the importance of health checkups or offer emotional support and encouragement for health-related matters?
# ✅ Done with concept generation!

# %%
l.summary()
# Out:
# Total time: 475.15 sec (7.92 min)
# 	('Distill-filter', '2025-07-31-13-50-06'): 185.94 sec
# 	('Distill-summarize', '2025-07-31-13-53-11'): 184.97 sec
# 	('Cluster', '2025-07-31-13-54-22'): 70.61 sec
# 	('Synthesize', '2025-07-31-13-54-50'): 28.01 sec
# 	('Review-remove', '2025-07-31-13-54-52'): 2.61 sec
# 	('Review-merge', '2025-07-31-13-54-55'): 3.02 sec
#
#
# Total cost: $2.70
# 	('Distill-filter', '2025-07-31-13-50-06'): $0.870
# 	('Distill-summarize', '2025-07-31-13-53-11'): $0.631
# 	('Synthesize', '2025-07-31-13-54-50'): $1.188
# 	('Review-remove', '2025-07-31-13-54-52'): $0.002
# 	('Review-merge', '2025-07-31-13-54-55'): $0.004
#
#
# Tokens: total=2462410, in=1952201, out=510209

# %%
l.select()
# Out:
# ConceptSelectWidget(data='{"5711b6ed-83b3-45dc-a1c5-4567cd6c903b": {"id": "5711b6ed-83b3-45dc-a1c5-4567cd6c903…

# %%
l.save(folder="./lloom_comments", file_name="before_scoring")
# Out:
# Saved session to ./lloom_comments/before_scoring.pkl

# %%
import pandas as pd
import json
import pickle
from datetime import datetime

# タイムスタンプ付きフォルダ
timestamp = datetime.now().strftime("%Y%m%d_%H%M%S")
save_dir = f"./lloom_backup_{timestamp}"
import os
os.makedirs(save_dir, exist_ok=True)

# 1. 生成されたコンセプトをJSON保存
concepts_data = {}
for c_id, concept in l.concepts.items():
  concepts_data[c_id] = concept.to_dict()

with open(f"{save_dir}/concepts.json", "w", encoding="utf-8") as f:
  json.dump(concepts_data, f, ensure_ascii=False, indent=2)

# 2. フィルター結果をCSV保存
if hasattr(l, 'df_filtered') and l.df_filtered is not None:
  l.df_filtered.to_csv(f"{save_dir}/filtered_data.csv",
index=False, encoding="utf-8")
  print(f"フィルター結果保存: {len(l.df_filtered)} rows")

# 3. 要約結果をCSV保存
if hasattr(l, 'df_bullets') and l.df_bullets is not None:
  l.df_bullets.to_csv(f"{save_dir}/bullet_summaries.csv",
index=False, encoding="utf-8")
  print(f"要約結果保存: {len(l.df_bullets)} rows")

# 4. 元データもバックアップ
l.in_df.to_csv(f"{save_dir}/original_data.csv", index=False,
encoding="utf-8")
# Out:
# フィルター結果保存: 5699 rows
# 要約結果保存: 11401 rows

# %%
  backup_info = {
      "timestamp": timestamp,
      "original_data_shape": l.in_df.shape,
      "filtered_data_shape": l.df_filtered.shape if hasattr(l,
  'df_filtered') and l.df_filtered is not None else None,
      "bullet_data_shape": l.df_bullets.shape if hasattr(l,
  'df_bullets') and l.df_bullets is not None else None,
      "num_concepts": len(l.concepts),
      "concept_names": [c.name for c in l.concepts.values()],
      "text_column": l.doc_col,
      "id_column": l.doc_id_col,
      "models": {
          "distill_model": l.distill_model.name if
  hasattr(l.distill_model, 'name') else str(l.distill_model),
          "score_model": l.score_model.name if
  hasattr(l.score_model, 'name') else str(l.score_model),
          "synth_model": l.synth_model.name if
  hasattr(l.synth_model, 'name') else str(l.synth_model),
          "cluster_model": l.cluster_model.name if
  hasattr(l.cluster_model, 'name') else str(l.cluster_model),
      }
  }

  with open(f"{save_dir}/backup_info.json", "w", encoding="utf-8") as f:
      json.dump(backup_info, f, ensure_ascii=False, indent=2)

  print("設定情報も保存完了")
# Out:
# 設定情報も保存完了

# %%
score_df = await l.score(
    score_all=True,
    sequential_processing=True,  # 逐次処理
    pivot_output=True,
    get_highlights=True,
    batch_size=3,
    debug=True  # 進捗表示を有効化
)
# Out:
# Scoring 6 concepts for 5699 documents (sequentially (one by one))
# Estimated cost: $1.44
# Note: Sequential processing provides better progress visibility and error handling
# Note: Output will be in pivot format (one row per document with all concept scores)
# **Please note that this is only an approximate cost estimate**
#
#
# Action required
# Proceed with scoring? (y/n):  y

# %%
import builtins
import sys

# inputを一時的にオーバーライド
def auto_confirm(prompt=""):
    print(f"{prompt}y", flush=True)
    return "y"

original_input = builtins.input
builtins.input = auto_confirm

try:
    score_df = await l.score(
        score_all=True,
        sequential_processing=True,
        pivot_output=True,
        get_highlights=True,
        batch_size=5,
        debug=True  # 進捗表示は維持
    )
finally:
    builtins.input = original_input

# %%
import text_lloom.src.text_lloom.workbench as wb
import pandas as pd
import os
from dotenv import load_dotenv
load_dotenv()
from text_lloom.src.text_lloom.llm import OpenAIModel

# %%
# 1. 修正が適用されているか確認
import importlib
import text_lloom.src.text_lloom.concept_induction as ci
importlib.reload(ci)  # モジュールをリロード
# Out:
# <module 'text_lloom.src.text_lloom.concept_induction' from '/home/takeh/lloom/text_lloom/src/text_lloom/concept_induction.py'>

# %%
# 後で復元する場合
import pickle

# セッション全体の復元
with open("./lloom_comments/before_scoring.pkl", "rb") as f:
  l = pickle.load(f)


l.select()
# Out:
# ConceptSelectWidget(data='{"5711b6ed-83b3-45dc-a1c5-4567cd6c903b": {"id": "5711b6ed-83b3-45dc-a1c5-4567cd6c903…

# %%
new_score_model = OpenAIModel(
  name="gpt-4.1-nano",  # または他のモデル
  api_key=os.environ["OPENAI_API_KEY"]
)

# 既存のインスタンスのスコアリングモデルを変更
l.score_model = new_score_model

# %%
await l.add(
    # Your new concept name
    name="ワクチン接種批判",
    # Your new concept prompt
    prompt="この文章はワクチン接種に対しての批判をしているか", 
)
# Out:
# Scoring 1 concepts for 5699 documents (in parallel)
# Estimated cost: $0.39
# **Please note that this is only an approximate cost estimate**
#
#
# Action required
# Proceed with scoring? (y/n):  y
#   0%|                                                                                                                                         | 0/1 [00:00<?, ?it/s]

# %%
l.select()

# %%
score_df = await l.score(
  score_all=True,
  sequential_processing=True, 
  pivot_output=True,
  get_highlights=True,
  batch_size=3,
  debug=True  
)
# Out:
# Scoring 6 concepts for 5699 documents (sequentially (one by one))
# Estimated cost: $1.44
# Note: Sequential processing provides better progress visibility and error handling
# Note: Output will be in pivot format (one row per document with all concept scores)
# **Please note that this is only an approximate cost estimate**
#
#
# Action required
# Proceed with scoring? (y/n):  y
# Sequential concept scoring: Processing 6 concepts one by one
#
# Processing concept 1/6: Medical Diagnosis
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "18",
#             "rationale": "The example mentions \u5b50\u5bae\u9838\u304c\u3093\u30ef\u30af\u30c1\u30f3\u and \u5c40\u90e8\u969c\u5bb3, which relate to health issues but do not specify a diagnosis or procedures.",
#             "answer": "D",
#             "quote": "\u5b50\u5bae\u9838\u304c\u3093\u30ef\u30af\u30c1\u30f3\n\u5c40\u90e8\u969c\u5bb3"
#         },
#         {
#             "example_id": "19",
#             "rationale": "The text mentions \u304c\u3093\u30ce\u30fc\u30c8\u60a3\u8005\u4f1a and \u5fdc\u63f4\u307e\u3059, indicating support for a patient group but not referencing any diagnosis or procedures.",
#             "answer": "D",
#             "quote": "\u304c\u3093\u30ce\u30fc\u30c8\u60a3\u8005\u4f1a\n\u5fdc\u63f4\u307e\u3059"
#         },
#         {
#             "example_id": "20",
#             "rationale": "The example discusses \u751f\u7406\u75db\u6642\u59cb\u307e\u308a\u524d\u751f\u7406\u697d and \u5b50\u5bae\u3051\u3044\u304c\u3093, which relate to physiological discomfort and a location, but do not mention specific diagnoses or procedures.",
#             "answer": "D",
#             "quote": "\u751f\u7406\u75db\u6642\u59cb\u307e\u308a\u524d\u751f\u7406\u697d"
#         }
#     ]
# }
# ERROR json_load on: {
#   "pattern_results": [
#     {
#       "example_id": "48",
#       "rationale": "The text discusses a condition without mentioning any specific medical diagnosis or procedures.",
#       "answer": "D",
#       "quote": "\u30ab\u30fc\u30c6\u30f3\u7121\u3057\u306e\u65b9\u304c\u307e\u3060\u7dba\u9e97"
#     },
#     {
#       "example_id": "49",
#       "rationale": "The example describes personal experiences and hospital visits but does not mention any medical diagnosis or procedures.",
#       "answer": "D",
#       "quote": "\u898b\u3084\u3059\u3044\u3093\u3058\u3083"
#     },
#     {
#       "example_id": "50",
#       "rationale": "The text mentions health-related concerns like "不快さ" and "痛み" but does not specify any diagnosis or procedures.",
#       "answer": "D",
#       "quote": "\u30ab\u30fc\u30c6\u30f3\u306e\u4e0d\u6f54\u3055\u306f\u76f2\u70b9\uff01"
#     }
#   ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "69",
#             "rationale": "The text discusses symptoms related to a doctor\'s diagnosis and internal examination, but does not explicitly mention a specific medical diagnosis or procedures like dysplasia or cancer.",
#             "answer": "D",
#             "quote": "\u533b\u5e2b\u306e\u6307\u3084\u81a3\u93e1\u304c\u304b\u306a\u308a\u75db\u304f\uff12\u65e5\u307b\u3069\u304a\u308a\u3082\u306e\u306b\u8840\u304c\u6df7\u3058\u3063\u3066\u3044\u307e\u3057\u305f\u3002"
#         },
#         {
#             "example_id": "70",
#             "rationale": "The example simply states "生理中" and "定期通院" without mentioning any diagnosis or procedures, indicating no explicit reference to medical diagnosis.",
#             "answer": "D",
#             "quote": "\u751f\u7406\u4e2d\n\u5b9a\u671f\u901a\u9662"
#         },
#         {
#             "example_id": "71",
#             "rationale": "The text mentions HPV and a question about its cause and treatment, but does not specify a diagnosis like dysplasia or cancer or related procedures.",
#             "answer": "D",
#             "quote": "\u672c\u5f53\u306bHPV\u304c\u5b50\u5bae\u9838\u304c\u3093\u306e\u539f\u56e0\u3067\u3059\u304b?"
#         }
#     ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "81",
#             "rationale": "The text discusses a medical examination and diagnosis, mentioning the absence of internal medicine diagnosis and subsequent examinations, indicating a medical context.",
#             "answer": "B",
#             "quote": "\u5185\u79d1\u7684\u306a\u8a3a\u5bdf\u304c\u306a\u3044\u306e\u306b\u3001\u5c11\u3057\u3073\u3063\u304f\u308a\u3057\u307e\u3057\u305f\u3002"
#         },
#         {
#             "example_id": "82",
#             "rationale": "The example states "LGBT\u3067\u3059" and does not mention any medical diagnosis or procedures, focusing instead on identity.",
#             "answer": "D",
#             "quote": "LGBT\u3067\u3059\u3002"
#         },
#         {
#             "example_id": "83",
#             "rationale": "The text describes symptoms and medical conditions such as pain and diagnosis, indicating a medical context involving diagnosis and procedures.",
#             "answer": "B",
#             "quote": "\u81a3\u93e1\u3092\u5165\u308c\u3089\u308c\u305f\u6642\u306b\u75db\u307f\u3092\u611f\u3058\u3001\u533b\u5e2b\u306b\u4f1d\u3048\u307e\u3057\u305f\u304c\u3001\u6df1\u547c\u5438\u3092\u3059\u308b\u3088\u3046\u8a00\u308f\u308c\u3001\u81a3\u93e1\u3092\u5e83\u3052\u3089\u308c\u307e\u3057\u305f\u3002"
#         }
#     ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "207",
#             "rationale": "The text discusses a doctor\'s diagnosis and symptoms related to blood and pain, but does not mention specific medical diagnoses or procedures.",
#             "answer": "D",
#             "quote": "\u533b\u5e2b\u306e\u6307\u3084\u81a3\u93e1\u304c\u304b\u306a\u308a\u75db\u304f\uff12\u65e5\u307b\u3069\u304a\u308a\u3082\u306e\u306b\u8840\u304c\u6df7\u3058\u3063\u3066\u3044\u307e\u3057\u305f\u3002"
#         },
#         {
#             "example_id": "208",
#             "rationale": "The example contains a casual phrase about a beauty and a broken mouth, with no mention of medical diagnosis or procedures.",
#             "answer": "D",
#             "quote": "\u3042\u3093\u305f\u7f8e\u4eba\u3084\u3051\n\u53e3\u501f\u308a\u3089\u308c\u305f\u3093\u3084\u308d"
#         },
#         {
#             "example_id": "209",
#             "rationale": "The text talks about cancer screening and mentions death, but does not specify a diagnosis like dysplasia or procedures.",
#             "answer": "C",
#             "quote": "\u764c\u691c\u8a3a\u306f\u3001\u5e74\u306b\u4e00\u5ea6\u3067\u306f\u306a\u304f\u307b\u3093\u3068\u3001\u983b\u7e41\u306b\u884c\u3063\u3066\u304a\u3044\u305f\u65b9\u304c\u3044\u3044\u3068\u601d\u3044\u307e\u3059(^^)"
#         }
#     ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "375",
#             "rationale": "The example discusses a woman\'s health check and clothing, with no mention of medical diagnoses or procedures.",
#             "answer": "D",
#             "quote": "\u5973\u6027\u305b\u30db\u30eb\u30e2\u30f3\u670d\u7528\u306f"
#         },
#         {
#             "example_id": "376",
#             "rationale": "The text describes a woman\'s examination and age, but does not mention any specific medical diagnosis or procedures.",
#             "answer": "D",
#             "quote": "\u9589\u7d4c\u3057\u305f\u5973\u6027\u306f\u3084\u3089\u306a\u304f\u3066\u3082\u554f\u984c\u306a\u3044\u3067\u3057\u3087\u3046\u304b"
#         },
#         {
#             "example_id": "377",
#             "rationale": "The example mentions an examination and a weather forecast, with no reference to medical diagnoses or procedures.",
#             "answer": "D",
#             "quote": "\u98a8\u25cb\u52e4\u52d9\u3067\u3059\u3002"
#         }
#     ]
# }
# ERROR json_load on: {
#   "pattern_results": [
#     {
#       "example_id": "450",
#       "rationale": "The text discusses government credit and trust, with no mention of medical diagnoses or procedures.",
#       "answer": "D",
#       "quote": "だか\u306f\u653f\u5e9c\u306f\u4fe1\u7528\u3067\u304d\u307e\u305b\u3093\u3002"
#     },
#     {
#       "example_id": "451",
#       "rationale": "The example talks about a person and a damage society, with no reference to medical conditions or procedures.",
#       "answer": "D",
#       "quote": "\u88fd\u85ac\u4f1a\u793e\u3068\u653f\u515a\u306e\u7652\u7740\u3092\u76ee\u306e\u5f53\u305f\u308a\u306b\u3057\u305f\u611f\u3058\u3002"
#     },
#     {
#       "example_id": "452",
#       "rationale": "The phrase "創価君" (Soka-kun) does not relate to any medical diagnosis or procedures mentioned in the text.",
#       "answer": "D",
#       "quote": "\u5275\u4fa1\u541b\u3088"
#     }
#   ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "690",
#             "rationale": "The text discusses medical concerns and prevention but does not mention any specific diagnosis or procedures related to diagnosis.",
#             "answer": "D",
#             "quote": "\u6ce8\u5c04\u3092\u6253\u3064\u3068\u591a\u5206\u5b50\u5bfa\u981a\u304c\u3093\u306e\u4e88\u9632\u3067\u304d\u308b\u3093\u3058\u3083\u306a\u3044\u304b\u306a\uff1f\u533b\u5b66\u7684\u306b\u306f\u591a\u5206\u3001\u88fd\u85ac\u4f1a\u793e\u3082\u6f64\u3046\u3057\u3044\u3044\u3093\u3058\u3083\u306a\u3044\u304b\u306a\uff1f\n\u3067\u3082\u30c7\u30e1\u30ea\u30c3\u30c8\u306f\u6ca2\u5c71\u3042\u308b\u3088\u3001\u795e\u7d4c\u969c\u5bb3\u306e\u5831\u544a\u3082\u6ca2\u5c71\u3042\u308b\u3057\u6210\u5206\u304c\u795e\u7d4c\u969c\u5bb3\u3092\u5f15\u304d\u8d77\u3053\u3057\u3066\u3082\u304a\u304b\u3057\u304f\u306a\u3044\u3057"},
#         "quote": "\u6ce8\u5c04\u3092\u6253\u3064\u3068\u591a\u5206\u5b50\u5bfa\u981a\u304c\u3093\u306e\u4e88\u9632\u3067\u304d\u308b\u3093\u3058\u3083\u306a\u3044\u304b\u306a\uff1f"
#     }
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "708",
#             "rationale": "The text discusses symptoms and conditions related to mental health and physical discomfort but does not mention any specific medical diagnosis or procedures.",
#             "answer": "D",
#             "quote": "\u81ea\u5206\u3082\u75d9\u6523\u306e\u526f\u4f5c\u7528\u304c\u51fa\u3066\u307e\u3059\u3057\u3001\u8db3\u3082\u60aa\u304f\u306a\u308a\u307e\u3057\u305f\u304c\u3001\u75c5\u9662\u306f\u7cbe\u795e\u7684\u3068\u304b\u3001\u6c17\u5206\u6b21\u7b2c\u3068\u304b\u610f\u5473\u308f\u304b\u3089\u306a\u3044\u3053\u3068\u3092\u3086\u3063\u3066\u3044\u307e\u3059"
#         },
#         {
#             "example_id": "709",
#             "rationale": "The example mentions a "wockchin" (likely "wockchin" as a typo or specific term) and discusses behaviors, but does not reference any medical diagnosis or procedures.",
#             "answer": "D",
#             "quote": "\u6b63\u76f4\u30ef\u30af\u30c1\u30f3\u306f\u6253\u3064\u524d\u306b\u4f55\u304c\u5165\u3063\u3066\u3044\u308b\u304b\u304f\u3089\u3044\u81ea\u5206\u3067\u8abf\u3079\u3066\u304b\u3089\u6253\u3064\u3079\u304d"
#         },
#         {
#             "example_id": "710",
#             "rationale": "The text asks about the safety of a medicine and a dangerous drug, but does not mention any diagnosis or related procedures.",
#             "answer": "D",
#             "quote": "\u5371\u967a\u30c9\u30e9\u30c3\u30b0\u3092\u3064\u304f\u3063\u305f\u4eba\u3063\u3066\u306a\u3093\u306a\u3093\u3060\u308d\u3046"
#         }
#     ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "792",
#             "rationale": "The text discusses Japanese men and their behavior, with no mention of medical diagnoses or procedures.",
#             "answer": "D",
#             "quote": "\u65e5\u672c\u306e\u7537\u5b50\u3082\u6253\u3063\u3066\u307b\u3057\u3044\u3002\n\u65e5\u672c\u3060\u3068\u5973\u304c\u6253\u3064\u3053\u3068\u3070\u304b\u308a\u63a8\u5968\u3055\u308c\u3066\u308b\u3088\u306d\u3002"
#         },
#         {
#             "example_id": "793",
#             "rationale": "The example describes emotional reactions and internal feelings, with no mention of medical diagnoses or procedures.",
#             "answer": "D",
#             "quote": "\u3053\u306e\u52d5\u753b\u5148\u306b\u898b\u3066\u3044\u305f\u3089\u3082\u3063\u3068\u30ea\u30e9\u30c3\u30af\u30b9\u3067\u304d\u305f\u306a\u301c\uff01\u3068\u601d\u3044\u307e\u3057\u305f\u3002\n\u5185\u8a3a\u53f0\u306b\u4e0a\u304c\u3063\u3066\u304b\u3089\u306f\u307b\u3093\u3068\u79d2\u3067\u7d42\u308f\u3063\u305f\u3057\u3001\u4f55\u56de\u3082\u53d7\u3051\u305f\u3044\u3082\u306e\u3067\u306f\u306a\u3044\u3051\u308c\u3069\u3001\u3082\u304e\u4e8c\u5ea6\u3068\u53d7\u3051\u305f\u304f\u306a\u3044\u3068\u306f\u601d\u308f\u306a\u3044\u3067\u6e08\u307f\u307e\u3057\u305f\u3002"
#         },
#         {
#             "example_id": "794",
#             "rationale": "The text discusses internal feelings and reactions to stress, with no mention of any medical diagnosis or procedures.",
#             "answer": "D",
#             "quote": "\u5185\u8a3a\u306f\u7dca\u5f35\u3057\u3066\u308b\u3068\u7121\u610f\u8b58\u306b\u529b\u3093\u3058\u3083\u3063\u3066\u75db\u304f\u306a\u308b\u304b\u3089\u3001\u3042\u3054\u3092\u5f15\u3044\u3066\u3086\u30fc\u3063\u304f\u308a\u6df1\u547c\u5438\u3059\u308b\u3088\u3046\u306b\u3059\u308b\u3068\u529b\u304c\u629c\u3051\u3066\u75db\u307f\u304c\u51fa\u306b\u304f\u3044\u6c17\u304c\u3057\u307e\u3059\u3002\n\u3082\u306e\u3059\u3054\u304f\u305f\u3081\u306b\u306a\u308b\u52d5\u753b\uff01\uff"
#         }
#     ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "918",
#             "rationale": "The example discusses various medical conditions and symptoms but does not mention any specific diagnosis or procedures related to medical diagnosis such as dysplasia or cancer.",
#             "answer": "D",
#             "quote": "\u30b5\u30fc\u30d0\u30ea\u30c3\u30af\u30b9\u306f\u6709\u5bb3\u4e8b\u8c61\u306e\u5831\u544a\u304c\u591a\u304f\u3001\u5931\u795e\u3092\u306f\u3058\u3081\u3001\u6025\u6027\u6563\u5728\u6027\u8133\u810a\u9ac4\u708e\uff08\uff21\uff24\uff25\uff2d\uff09\u3001\u75d9\u6523\uff08\u3051\u3044\u308c\u3093\uff09\u3001\u30ae\u30e9\u30f3\u30d0\u30ec\u30fc\u75c7\u5019\u7fa4\uff08\uff27\uff22\uff33\uff09\u3001\u\uff33\uff2c\uff25 (\u5168\u8eab\u6027\u30a8\u30ea\u30c6\u30de\u30c8\u30fc\u30c9\u30b9\uff09\u3001\u82e5\u5e74\u6027\u95a2\u7bc0\u708e\u3001\u672b\u68a2\u51b7\u611f\u3001\u96e3\u6cbb\u6025\u75bc\u75db\u3001\u6b69\u884c\u969c\u5bb3\u3001\u56db\u80a2\u75db\u3001\u56db\u80a2\u306e\u904b\u52d5\u4f4e\u4e0b\u3001\u7b4b\u529b\u4f4e\u4e0b\u3001\u7b4b\u9aa8\u683c\u75db\u3001\u611f\u899a\u920d\u9ebb\u3001\u8a08\u7b97\u80fd\u529b\u306e\u4f4e\u4e0b\u306a",
#             "answer": "D",
#             "quote": "\u30b5\u30fc\u30d0\u30ea\u30c3\u30af\u30b9\u306f\u6709\u5bb3\u4e8b\u8c61\u306e\u5831\u544a\u304c\u591a\u304f\u3001\u5931\u795e\u3092\u306f\u3058\u3081\u3001\u6025\u6027\u6563\u5728\u6027\u8133\u810a\u9ac4\u708e\uff08\uff21\uff24\uff25\uff2d\uff09\u3001\u75d9\u6523\uff08\u3051\u3044\u308c\u3093\uff09\u3001\u30ae\u30e9\u30f3\u30d0\u30ec\u30fc\u75c7\u5019\u7fa4\uff08\uff27\uff22\uff33\uff09\u3001\uff33\uff2c\uff25 (\u5168\u8eab\u6027\u30a8\u30ea\u30c6\u30de\u30c8\u30fc\u30c9\u30b9\uff09\u3001\u82e5\u5e74\u6027\u95a2\u7bc0\u708e\u3001\u672b\u68a2\u51b7\u611f\u3001\u96e3\u6cbb\u6025\u75bc\u75db\u3001\u6b69\u884c\u969c\u5bb3\u3001\u56db\u80a2\u75db\u3001\u56db\u80a2\u306e\u904b\u52d5\u4f4e\u4e0b\u3001\u7b4b\u529b\u4f4e\u4e0b\u3001\u7b4b\u9aa8\u683c\u75db\u3001\u611f\u899a\u920d\u9ebb\u3001\u8a08\u7b97\u80fd\u529b\u306e\u4f4e\u4e0b\u306a"
#         }
#     ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "987",
#             "rationale": "The text discusses a past event related to a medical examination and a future plan, but does not mention any specific diagnosis or procedures.",
#             "answer": "D",
#             "quote": "\u53bb\u5e74\u306e\u5e74\u672b\u9803\u306b\u3001\u5de8\u5927\u306a\u5b50\u5bae\u7b4b\u816b\u304c\u898b\u3064\u304b\u3063\u3066\u3001\u305d\u3057\u3066\u5b50\u5bae\u9838\u304c\u3093\u306e\u691c\u67fb\u306b\u3082\u5f15\u3063\u304b\u304b\u308a\u2026\u4eca\u5e74\u306e\u521d\u590f\u9803\u624b\u8853\u306e\u4e88\u5b9a\u3060\u3088\u2026"
#         },
#         {
#             "example_id": "988",
#             "rationale": "The text provides a time and location for an activity but does not mention any medical diagnosis or procedures.",
#             "answer": "D",
#             "quote": "4:30~\n\u30de\u30b8\u3067\u3053\u308c"
#         },
#         {
#             "example_id": "989",
#             "rationale": "The text discusses clothing and a general request for action, with no mention of any medical diagnosis or procedures.",
#             "answer": "D",
#             "quote": "\u5f3e\u6027\u7740\u8863\u306e\u5fc5\u8981\u306a\u65b9\u306f\u3001\u30ea\u30f3\u30d1\u30ec\u30c3\u30c4\u306e\u30db\u30fc\u30e0\u30da\u30fc\u30b8\u306b\u3082\u662f\u975e\u30a2\u30af\u30bb\u30b9\u3057\u3066\u307f\u3066\u304f\u3060\u3055\u3044\u3002\n\u304a\u4f53\u306b\u3042\u3063\u305f\u3082\u306e\u304c\u898b\u3064\u304b\u308b\u3068\u601d\u3044\u307e\u3059\uff"
#         }
#     ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "1044",
#             "rationale": "The text discusses feelings and a general context without mentioning any specific medical diagnosis or procedures.",
#             "answer": "E",
#             "quote": "\u304a\u5143\u6c17\u3068\u306e\u3053\u3068\u3067\u3059\u304c\u5fc3\u914d\u3067\u3059"
#         },
#         {
#             "example_id": "1045",
#             "rationale": "The example mentions a diagnosis ("\u8a3a\u65ad") and a desire for examination, indicating a medical context related to diagnosis, but no specific diagnosis or procedures are named.",
#             "answer": "B",
#             "quote": "\u81ea\u5206\u304c\u8a3a\u65ad\u3055\u308c\u305f\u4ee5\u4e0a\u5468\u308a\u306e\u5927\u5b66\u751f\u306b\u306f\u691c\u8a3a\u306b\u884c\u3063\u3066\u6b32\u3057\u3044\u3068\u601d\u3044\u307e\u3057\u305f"
#         },
#         {
#             "example_id": "1046",
#             "rationale": "The text expresses a general greeting and inquiry without any mention of medical diagnoses or procedures.",
#             "answer": "E",
#             "quote": "\u691c\u67fb\u3082\u6016\u3044\u3067\u3059\u3088\u306d\u3002\u3002\u9811\u5f35\u308a\u307e\u3059"
#         }
#     ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "1065",
#             "rationale": "The text discusses a medical examination and diagnosis but does not specify any particular diagnosis or procedures related to dysplasia or cancer.",
#             "answer": "D",
#             "quote": "\u691c\u8a3a\u306f\u672c\u5f53\u5927\u4e8b\u3067\u3059\u306d\u30fc\uff01\u3053\u308c\u304b\u3089\u306e\u691c\u67fb\u7d50\u679c\u6b21\u7b2c\u3067\u306f\u3042\u308a\u307e\u3059\u304c\u3001\u79c1\u3082\u75c5\u6c17\u306b\u8ca0\u3051\u305a\u306b\u9811\u5f35\u308a\u307e\u3059"}
#         },
#         {
#             "example_id": "1066",
#             "rationale": "The example mentions pain and physical discomfort but does not mention any diagnosis or procedures related to medical conditions like dysplasia or cancer.",
#             "answer": "D",
#             "quote": "\u75db\u307f\u306b\u7269\u51c4\u304f\u5f31\u3044\u306e\u3067\u3059\u304c\n\u898b\u3066\u308b\u3060\u3051\u3067\u75db\u3044\u2026\u2026\u2026"
#         },
#         {
#             "example_id": "1067",
#             "rationale": "The text describes a surgical procedure and a general health condition but does not specify any particular diagnosis such as dysplasia or cancer or related procedures.",
#             "answer": "D",
#             "quote": "\u7121\u4e8b\u624b\u8853\u304c\u7d42\u308f\u308c\u3066\u3001\u672c\u5f53\u306b\u826f\u304b\u3063\u305f\u3067\u3059\uff01"
#         }
#     ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "1143",
#             "rationale": "The text mentions HPV and a medical professional, but does not specify a diagnosis or related procedures.",
#             "answer": "D",
#             "quote": "\u91d1\u5132\u3051\u306e\u81ed\u3044\u304c\u30d7\u30f3\u30d7\u30f3\u3059\u308b\u308f\u2757"
#         },
#         {
#             "example_id": "1144",
#             "rationale": "The example discusses causes and effects related to medical procedures but does not mention a specific diagnosis or procedure directly.",
#             "answer": "D",
#             "quote": "\u5be7\u308d\u526f\u4f5c\u7528\u306b\u56e0\u679c\u95a2\u4fc2\u306f\u306a\u3044\u3068\u3057\u3066\u526f\u4f5c\u7528\u306e\u539f\u56e0\u7a76\u660e\u3092\u5b8c\u5168\u653e\u68c4\u3057\u3066\u3044\u308b\u63a8\u9032\u6d3e\u533b\u5e2b\u306e\u59ff\u52e2\u3053\u305d\u304cHPV\u30ef\u30af\u30c1\u30f3\u306b\u5bfe\u3059\u308b\u4e0d\u4fe1\u611f\u306e\u4e00\u7aef\u306a\u306e\u3067\u306a\u3044\u304b\u3068\u601d\u3046\u3093\u3067\u3059\u3088\u306d\u3002",
#         }
#         ,
#         {
#             "example_id": "1145",
#             "rationale": "The text discusses recurrence and examination results but does not mention any specific diagnosis or related procedures.",
#             "answer": "D",
#             "quote": "\u6\u5e74\u5f8c\u816b\u7624\u7591\u3044\u306b\u306a\u308a\u518d\u691c\u67fb\u3002\u518d\u691c\u67fb\u7570\u5e38\u306a\u3044\u3001\u7fcc\u5e74\u3082\u7570\u5e38\u306a\u3057\u3002"
#         }
#     ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "1302",
#             "rationale": "The text discusses the shape and degree of dysplasia, indicating a mention of a medical diagnosis related to tissue abnormality.",
#             "answer": "A",
#             "quote": "軽度異形成から中度異形成になりました。"
#         },
#         {
#             "example_id": "1303",
#             "rationale": "The example describes a past event involving a procedure (wakarichn) and lifestyle changes, with no mention of a diagnosis or related procedures.",
#             "answer": "D",
#             "quote": "過去にワカチンをうって患畜したり車椅子生活に"
#         },
#         {
#             "example_id": "1304",
#             "rationale": "The text mentions a "子宮体" (uterus body) and a follow-up after half a year, but does not specify any diagnosis or procedures.",
#             "answer": "D",
#             "quote": "子宮体がんステージわんえー"
#         }
#     ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "1386",
#             "rationale": "The text discusses physiological and hospital-related issues but does not mention any specific medical diagnosis or procedures.",
#             "answer": "D",
#             "quote": "\u75c5\u9662\u306b\u884c\u3063\u305f\u65b9\u304c\u3044\u3044\u306e\u3067\u3057\u3087\u3046\u304b\uff1f"
#         },
#         {
#             "example_id": "1387",
#             "rationale": "The example talks about blood and health but does not specify any diagnosis or related procedures.",
#             "answer": "D",
#             "quote": "\u4e0d\u6b63\u51fa\u8840\u3067\u764c\u304c\u898b\u3064\u304b\u308a\u307e\u3057\u305f\u3002"
#         },
#         {
#             "example_id": "1388",
#             "rationale": "The example simply states "I am also" without any mention of medical diagnoses or procedures.",
#             "answer": "D",
#             "quote": "\u79c1\u3082\u3067\u3059\u3002"
#         }
#     ]
# }
# ERROR json_load on: {
#   "pattern_results": [
#     {
#       "example_id": "1494",
#       "rationale": "The text discusses a health condition involving pain and a diagnosis, but does not mention specific medical diagnoses like dysplasia or cancer or related procedures.",
#       "answer": "D",
#       "quote": "\u5b子\u5bae\u4f53\u304c\u3093\u691c\u67fb\u306f\uff13\u5e74\u524d\u521d\u3081\u3066\u53d7\u3051\u305f\u3068\u304d\u75db\u304f\u3066\u75db\u304f\u3066\u672c\u5f53\u306b\u30c8\u30e9\u30a6\u30de\u306b\u306a\u308a\u307e\u3057\u305f\u3002"
#     },
#     {
#       "example_id": "1495",
#       "rationale": "The text mentions a diagnosis of a specific disease (cancer) and a procedure (diagnosis), indicating a focus on medical diagnosis.",
#       "answer": "A",
#       "quote": "\u5b子\u5bae\u4f53\u764c\u691c\u67fb \u5b子\u5bae\u9838\u304c\u3093\u691c\u67fb \u5927\u9a12\u304e\u3059\u308b\u7a0b\u75db\u304f\u3042\u308a\u307e\u305b\u3093\u3067\u3057\u305f\u3002"
#     },
#     {
#       "example_id": "1496",
#       "rationale": "The text contains questions about a person and future plans, with no mention of any medical diagnosis or procedures.",
#       "answer": "E",
#       "quote": "\u5b6b\u306f\u3044\u3064\u3060\uff1f\n\u6765\u5e74\u304b\u306a\uff1f"
#     }
#   ]
# }
# ERROR json_load on: {
#   "pattern_results": [
#     {
#       "example_id": "1566",
#       "rationale": "The text discusses medical conditions and treatments, mentioning 'HPV\u30ef\u30af\u30c1\u30f3' and '\u75c5\u6c17', indicating a focus on medical diagnosis and procedures.",
#       "answer": "A",
#       "quote": "\u300cHPV\u30ef\u30af\u30c1\u30f3\uff08\u5b50\u5bae\u9838\u304c\u3093\u7b49\u4e88\u9632\uff09\u3092\u6253\u3064\u6a5f\u4f1a\u3092\u596a\u308f\u308c\u305f\u82e5\u8005\u305f\u3061\u304c\u7121\u6599\u3067\u63a5\u7a2e\u3059\u308b\u30c1\u30e3\u30f3\u30b9\u3092\u304f\u3060\u3055\u3044\u300d"},
#       "quote": "\u300cHPV\u30ef\u30af\u30c1\u30f3\uff08\u5b50\u5bae\u9838\u304c\u3093\u7b49\u4e88\u9632\uff09\u3092\u6253\u3064\u6a5f\u4f1a\u3092\u596a\u308f\u308c\u305f\u82e5\u8005\u305f\u3061\u304c\u7121\u6599\u3067\u63a5\u7a2e\u3059\u308b\u30c1\u30e3\u30f3\u30b9\u3092\u304f\u3060\u3055\u3044\u300d"}
#     },
#     {
#       "example_id": "1567",
#       "rationale": "The text mentions HPV and health-related concerns, but does not specify any diagnosis or procedures, focusing instead on general health and vaccination.",
#       "answer": "D",
#       "quote": "\u3053\u308c\u3067\u307e\u305fHPV\u30ef\u30af\u30c1\u30f3\u3092\u53d7\u3051\u308b\u4eba\u3084\u7a4d\u6975\u7684\u52e7\u5968\u3078\u5207\u308a\u66ff\u3048\u308b\u81ea\u6cbb\u4f53\u304c\u5897\u3048\u3066\u307b\u3057\u3044\u3002"
#     },
#     {
#       "example_id": "1568",
#       "rationale": "The text describes symptoms related to side effects after vaccination, but does not mention any specific diagnosis or medical procedures.",
#       "answer": "D",
#       "quote": "\u30ef\u30af\u30c1\u30f3\u3092\u6253\u3063\u3066\u5f37\u3044\u526f\u53cd\u5fdc\u304c\u51fa\u3066\u5f8c\u907a\u75c7\u304c\u6b8b\u3063\u305f\u5834\u5408"
#     }
#   ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "1575",
#             "rationale": "The text discusses a transfer to a hospital and hospitalization but does not mention any medical diagnosis or procedures.",
#             "answer": "D",
#             "quote": "\u4e0d\u5b89\u3067\u3044\u3063\u3071\u3044\u3067\u3059\u3002"
#         },
#         {
#             "example_id": "1576",
#             "rationale": "The example mentions the experience of trust and communication but does not refer to any medical diagnosis or procedures.",
#             "answer": "D",
#             "quote": "\u7d4c\u9a13\u8005\u3068\u3057\u3066\u306e\u767a\u4fe1"
#         },
#         {
#             "example_id": "1577",
#             "rationale": "The text talks about children not being able to go out and marriage, with no mention of medical diagnoses or procedures.",
#             "answer": "D",
#             "quote": "\u62\u5b50\u3069\u3082\u51fa\u6765\u306a\u3044\u304b\u308d\u306d"
#         }
#     ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "1689",
#             "rationale": "The text discusses a recurrence and diagnosis related to a medical condition, indicating a mention of a diagnosis.",
#             "answer": "B",
#             "quote": "\u518d\u767a\u306b\u5e38\u306b\u602f\u3048\u3066\u3044\u307e\u3059\u3002"
#         },
#         {
#             "example_id": "1690",
#             "rationale": "The example describes examination results and diagnoses by a doctor, explicitly mentioning medical diagnosis and procedures.",
#             "answer": "A",
#             "quote": "\u533b\u5e2b\u304b\u3089\u306f\u5168\u6458\u3092\u52e7\u3081\u3089\u308c\u307e\u3057\u305f\u304c"
#         },
#         {
#             "example_id": "1691",
#             "rationale": "The text states "I am a sun person" and discusses feelings and internal states, with no mention of medical diagnoses or procedures.",
#             "answer": "E",
#             "quote": "\u79c1\u306f\u967d\u6027\u3067\u3057\u305f\u3002"
#         }
#     ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "1905",
#             "rationale": "The text discusses a child's throat condition and hospital care but does not mention any specific medical diagnosis or procedures.",
#             "answer": "D",
#             "quote": "\u5b50\u5bae\u9838\u304c\u3093\u30ef\u30af\u30c1\u30f3\u306e\u4ef6\u3068\u81ea\u5b85\u7642\u990a\u4e2d\u306e\u305f\u3081\u3001\u30b3\u30ed\u30ca\u30ef\u30af\u30c1\u30f3\u306f\u3001\u307e\u3060\u5148\u3067\u3001\u3044\u3048\u3063\u3066\u3044\u307e\u3057\u305f\u304c\u3001\u901a\u9662\u306a\u3069\u3067\u3001\u5916\u51fa\u3059\u308b\u4e8b\u3082\u3000\u3042\u308b\u306e\u3067\u3001\u6253\u3064\u3053\u3068\u306b\u306b\u3057\u307e\u305f\u3002"
#         },
#         {
#             "example_id": "1906",
#             "rationale": "The example contains a mention of a "dairy" and "dairy products" but no mention of any medical diagnosis or procedures.",
#             "answer": "D",
#             "quote": "\u8ff7\u3001\u30c9\u30e9\u30a4\u30d0\u30fc\n\u5927\u77f3\u30c9\u30e9\u30a4\u30d0\u30fc\ud83d\ude06\ud83d\udc4d"
#         },
#         {
#             "example_id": "1907",
#             "rationale": "The text talks about election results and emotional reactions but does not mention any medical diagnosis or related procedures.",
#             "answer": "D",
#             "quote": "\u3053\u306e\u5ea6\u306e\u9078\u6319\u3067\u9006\u5883\u306b\u3082\u6ec5\u6c17\u305a\u52dd\u5229\u3092\u52dd\u3061\u53d6\u308a\u307e\u3057\u305f\u306d\uff01"
#         }
#     ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "2046",
#             "rationale": "The text discusses expectations and understanding related to a person and their intentions, with no mention of medical diagnoses or procedures.",
#             "answer": "D",
#             "quote": "\u5e0c\u671b\u3059\u308b\u4eba\u306b\u306f\u3001\u63a5\u7a2e\u3057\u3084\u3059\u3044\u3088\u3046\u306b\u3002\n\u6b63\u3057\u3044\u60c5\u5831\u3067\u672c\u4eba\u304c\u5224\u65ad\u3057\u3066\u3001\u672c\u4eba\u306e\u610f\u601d\u3001\u5e0c\u671b\u3067\u63a5\u7a2e\u3059\u308b\u3002"
#         },
#         {
#             "example_id": "2047",
#             "rationale": "The example mentions information differences and formatting issues but does not reference any medical diagnosis or procedures.",
#             "answer": "D",
#             "quote": "\u300c\u8a8d\u3081\u306a\u3044\u300d\u3068\u300c\u524d\u4f8b\u304c\u306a\u3044\u300d\u306e\u30eb\u30fc\u30d7\u3067\u526f\u53cd\u5fdc\u6570\u306f\u5897\u3048\u307e\u305b\u3093\u3002\n\u60c5\u5831\u683c\u5dee\u304c\u3042\u308b\u3068\u8a00\u3044\u307e\u3059\u304c\u30ef\u30af\u306e\u4e2d\u8eab\u306e\u8a73\u7dd\u3068\u3044\u3063\u3057\u3087\u306b\u300e\u6dfb\u4ed8\u6587\u66f8\u300f\u3082\u5927\u3005\u7684\u306b\u516c\u8868\u3059\u3079\u304d\u3068\u601d\u3044\u307e\u3059\u3002"
#         },
#         {
#             "example_id": "2048",
#             "rationale": "The text describes a tragic event involving a woman and a dangerous situation, with no mention of any medical diagnosis or related procedures.",
#             "answer": "D",
#             "quote": "\u5148\u9032\u56fd\u306b\u3082\u304b\u304b\u308f\u3089\u305a\u5b50\u5bae\u981a\u304c\u3093\u3067\u4ea1\u304f\u306a\u3063\u305f\u5973\u6027\u306f\u3069\u308c\u3060\u3051\u3044\u308b\u3053\u3068\u3060\u308d\u3046\u304b"
#         }
#     ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "2094",
#             "rationale": "The text discusses taxes, government, and economic terms without mentioning any medical diagnosis or procedures.",
#             "answer": "D",
#             "quote": "\u653f\u5e9c\u306f\"\u7bc0\u7a0e\"\u306e\u305f\u3081\u306b\u30ce\u30a4\u30b8\u30fc\u30de\u30a4\u30ce\u30ea\u30c6\u30a3\u306b\u5c48\u3057\u305f\u3075\u308a\u3092\u3057\u3066\u6442\u53d6\u547c\u3073\u304b\u3051\u3092\u8f9e\u3081\u305f\u3093\u3058\u3083\u306a\u3044\u306e\u304b\u30fc\u30fc\u30fc"
#         },
#         {
#             "example_id": "2095",
#             "rationale": "The example mentions taxes, age, and economic issues but does not reference any medical diagnosis or related procedures.",
#             "answer": "D",
#             "quote": "\u653f\u5e9c\u304c\u547c\u3073\u304b\u3051\u3092\u8f9e\u3081\u305f\u306e\u306f\u3001\u30ce\u30a4\u30b8\u30fc\u30de\u30a4\u30ce\u30ea\u30c6\u30a3\u306e\u305b\u3044\u3067\u306f\u306a\u304f\u7bc0\u7a0e\u3067\u306f\u3002"
#         },
#         {
#             "example_id": "2096",
#             "rationale": "The text discusses gender, infection, and lifestyle but does not mention any medical diagnosis or procedures.",
#             "answer": "D",
#             "quote": "\u5973\u6025\u306e\u80%\u4ee5\u4e0a\u304c\u4eba\u751f\u306b\u4e00\u5ea6\u306f\u7537\u6027\u306e\u6301\u3064\u3053\u306e\u30a6\u30a4\u30eb\u30b9\u306b\u611f\u67d3\u3059\u308b\u3002"
#         }
#     ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "2149",
#             "rationale": "The example discusses HPV and the desire to have a baby, with no mention of any medical diagnosis or procedures.",
#             "answer": "D",
#             "quote": "\u7537\u6027\u306b\u3082\u6709\u52b9\u306a\u30ef\u30af\u30c1\u30f3\uff08\u7537\u3082hpv\u7531\u6765\u306e\u30ac\u30f3\u306b\u304b\u304b\u308b\u3088\uff09\u3060\u304b\u3089\u3001\u56fd\u8ca0\u62c5\u3067\u63a5\u7a2e\u3057\u305f\u3044\u4eba\u304c\u51fa\u6765\u308b\u69d8\u306b\u306a\u308b\u3079\u304d\u301c"
#         },
#         {
#             "example_id": "2150",
#             "rationale": "The text mentions health conditions and hospital procedures but does not specify any diagnosis or related medical procedures.",
#             "answer": "D",
#             "quote": "\u5730\u65b9\u306e\u75c5\u7406\u6280\u5e2b\u306a\u3093\u3060\u3051\u3069\u6bce\u65e52\u301c3\u4eba\u5b50\u5bae\u9838\u304c\u3093\u3060\u3068\u304bCIS2\u3068\u304b\u3067\u5b50\u5bae\u9838\u90e8\u5207\u9664\u3068\u304b\u5b50\u5b\u5168\u6458\u51fa\u3068\u304b\u3055\u308c\u3066\u308b\u4eba\u7d76\u3048\u306a\u3044\u3088"
#         },
#         {
#             "example_id": "2151",
#             "rationale": "The example discusses final relationships and human interactions without any mention of medical diagnoses or procedures.",
#             "answer": "D",
#             "quote": "\u3069\u3061\u3089\u3082\u6700\u7d42\u30ea\u30b9\u30af\u306f\u540c\u3058\u3068\u8a00\u3048\u308b\u304c\u3001\u500b\u4eba\u3068\u3057\u3066\u306f\u3001\u5f8c\u8005\u306f\u6253\u3064\u306e\u3092\u8e8a\u8e87\u3046\u4eba\u9593\u304c\u51fa\u308b\u3002"
#         }
#     ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "2188",
#             "rationale": "The text discusses medical conditions and the importance of diagnosis, but does not mention specific diagnoses or procedures.",
#             "answer": "D",
#             "quote": "このチャネルでは大切なことも、エンタメと交えて伝えられるのでお願い申し上げます"
#         },
#         {
#             "example_id": "2189",
#             "rationale": "The example talks about a "ケーキ" (cake) and eating, with no mention of medical diagnoses or procedures.",
#             "answer": "D",
#             "quote": "ケーキいいですね。クリスマスイヴだけ食べます。"
#         },
#         {
#             "example_id": "2190",
#             "rationale": "The text mentions personal preferences and feelings, with no reference to any medical diagnosis or related procedures.",
#             "answer": "D",
#             "quote": "個人的に\uff32\uff30、もっと短いほうが好きです。"
#         }
#     ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "2248",
#             "rationale": "The text discusses HPV infection and side effects but does not mention any specific medical diagnosis or procedures related to dysplasia or cancer.",
#             "answer": "D",
#             "quote": "\u526f\u53cd\u5fdc\u306e\u5831\u9053\u304c\u3042\u3063\u305f\u3051\u3069\u3042\u308c\u306f\u526f\u53cd\u5fdc\u3058\u3083\u306a\u304f\u3066\u6709\u5bb3\u4e8b\u8c61\u306d\u3000\u30ef\u30af\u30c1\u30f3\u306e\u5185\u5bb9\u306b\u3088\u308b\u3082\u306e\u3067\u306a\u3044"},
#             "quote": "\u526f\u53cd\u5fdc\u306e\u5831\u9053\u304c\u3042\u3063\u305f\u3051\u3068"
#         },
#         {
#             "example_id": "2249",
#             "rationale": "The example describes feelings of fatigue and emotional distress without mentioning any diagnosis or related procedures.",
#             "answer": "D",
#             "quote": "\u307f\u3093\u306a\u6bce\u65e5\u306b\u75b2\u308c\u305f\u308a\u5fc3\u914d\u306a\u3053\u3068\u305f\u304f\u3055\u3093\u3067\u3057\u3093\u3069\u304f\u306a\u3063\u305f\u3089",
#             "quote": "\u307f\u3093\u306a\u6bce\u65e5\u306b\u75b2\u308c\u305f\u308a\u5fc3\u914d\u306a\u3053\u3068\u305f\u304f\u3055\u3093\u3067\u3057\u3093\u3069\u304f\u306a\u3063\u305f\u3089"
#         },
#         {
#             "example_id": "2250",
#             "rationale": "The text expresses feelings of fear and discomfort but does not mention any specific diagnosis or medical procedures.",
#             "answer": "D",
#             "quote": "\u306a\u3093\u304b\u5371\u6a5f\u611f\u611f\u3058\u305f\u2026\u3067\u3082\u4e00\u4eba\u3067\u884c\u304f\u306e\u6016\u3044\u3088\u2026",
#             "quote": "\u5165\u308b\u3060\u3051\u3067\u4f53\u8abf\u60aa\u304f\u306a\u308b\u3050\u3089\u3044\u75c5\u9662\u5acc\u3044\u306a\u306e\u306b\u2026"
#         }
#     ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "2263",
#             "rationale": "The text discusses PCOS and related reproductive health issues but does not mention any specific medical diagnosis or procedures.",
#             "answer": "D",
#             "quote": "\u6fc3\u3044\u7537\u6027\u4e26\u307f\u3001\u30cb\u30ad\u30d3\u304c\u306a\u3044\u65e5\u304c\u307b\u307c\u306a\u3044\u3001\u751f\u7406\u4e0d\u9806\u30672\u30f6\u6708\u751f\u7406\u3053\u306a\u3044\u3068\u304b\u30b6\u30e9\u3067\u591a\u5206PCOS\u306a\u3093\u3060\u308d\u3046\u306a\u3068\u601d\u3044\u306a\u304c\u3089\u3082\u5a66\u4eba\u79d1\u6016\u3044\u3057\u3081\u3093\u3069\u304f\u3055\u3044\u3057\u6065\u305a\u304b\u3057\u3044\u304b\u3089\u884c\u3051\u306a\u3044\u307e\u307e25\u6b73\u306b\u306a\u308a\u307e\u3057\u305f\u2026"
#         },
#         {
#             "example_id": "2264",
#             "rationale": "The text mentions symptoms and conditions but does not specify any diagnosis or procedures.",
#             "answer": "D",
#             "quote": "\u708e\u75c7\u30a2\u30ea\u3001\u3063\u3066\u66f8\u3044\u3066\u3042\u3063\u305f"
#         },
#         {
#             "example_id": "2265",
#             "rationale": "The example talks about routine checkups and concerns but does not mention any specific medical diagnosis or procedures.",
#             "answer": "D",
#             "quote": "\u8efd\u5ea6\u7570\u5f62\u6210\u306e\u7591\u3044\u304c\u3042\u308b\u306e\u3067\u5927\u304d\u3044\u75c5\u9662\u3067\u691c\u67fb\u3057\u3066\u304f\u3060\u3055\u3044\u3068\u901a\u77e5\u304c\u6765\u307e\u3057\u305f\u00f0\u83d\ude2d"
#         }
#     ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "2323",
#             "rationale": "The text discusses a woman who died after visiting a shrine and mentions danger, but does not mention any medical diagnosis or procedures.",
#             "answer": "D",
#             "quote": "\u5148\u9032\u56fd\u306b\u3082\u304b\u304b\u308f\u3089\u305a\u5b50\u5bae\u981a\u304c\u3093\u3067\u4ea1\u304f\u306a\u3063\u305f\u5973\u6027\u306f\u3069\u308c\u3060\u3051\u3044\u308b\u3053\u3068\u3060\u308d\u3046\u304b"
#         },
#         {
#             "example_id": "2324",
#             "rationale": "The example mentions a cause related to a "wakichin" but does not reference any medical diagnosis or procedures.",
#             "answer": "D",
#             "quote": "\u300c\u30ef\u30af\u30c1\u30f3\u3068\u306e\u56e0\u679c\u95a2\u4fc2\u304c\u7121\u3044\u300d"
#         },
#         {
#             "example_id": "2325",
#             "rationale": "The text describes a person becoming a half-body and a feeling of regret, with no mention of any medical diagnosis or procedures.",
#             "answer": "D",
#             "quote": "\u4e0b\u534a\u8eab\u4ed8\u968f\u306b\u306a\u3063\u305f\u53cb\u4eba"
#         }
#     ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "2398",
#             "rationale": "The text discusses national officials and economic concerns without mentioning any medical diagnosis or procedures.",
#             "answer": "D",
#             "quote": "\u8ca1\u52d9\u7701\u304c\u53cd\u7dca\u7e2e\u306b\u306a\u308b\u306e\u306f100\u5e74\u5f8c\u304b\u7b11"
#         },
#         {
#             "example_id": "2399",
#             "rationale": "The example asks a question about necessity and does not mention any medical diagnosis or related procedures.",
#             "answer": "D",
#             "quote": "\u3053\u3093\u306a\u306e\u5fc5\u8981\u3042\u308b\uff1f"
#         },
#         {
#             "example_id": "2400",
#             "rationale": "The text simply states "evil spirit" without any mention of medical diagnoses or procedures.",
#             "answer": "D",
#             "quote": "\u60aa\u9b54"
#         }
#     ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "2428",
#             "rationale": "The text discusses medical treatments and side effects but does not mention any specific medical diagnosis or procedures.",
#             "answer": "D",
#             "quote": "\u7a4d\u6975\u63a8\u5968\u3059\u308b\u4ee5\u4e0a\u306f\u526f\u4f5c\u7528\u3067\u82e6\u3057\u3080\u4eba\u9054\u306b\u304d\u3061\u3093\u3068\u3057\u305f\u88dc\u511f\u3084\u6cbb\u7642\u3082\u30bb\u30c3\u30c8\u3067\u8003\u3048\u306a\u3044"},
#             "quote": "\u7a4d\u6975\u63a8\u5968\u3059\u308b\u4ee5\u4e0a\u306f\u526f\u4f5c\u7528\u3067\u82e6\u3057\u3080\u4eba\u9054\u306b\u304d\u3061\u3093\u3068\u3057\u305f\u88dc\u511f\u3084\u6cbb\u7642\u3082\u30bb\u30c3\u30c8\u3067\u8003\u3048\u306a\u3044"
#         }
#     ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "2665",
#             "rationale": "The text discusses symptoms and experiences related to a medical condition but does not mention any specific diagnosis or procedures.",
#             "answer": "D",
#             "quote": "\u6027\u4ea4\u7d4c\u9a13\u306f\u306a\u3044\u306e\u3067\u3059\u304c\u3001\u5375\u5de3\u56a2\u816b\u304c\u4e9c\u637b\u8ee2\u3057\u305f\u6642\u306b\u3001\u3084\u3080\u3092\u5f97\u305a\u7d4c\u81a3\u30a8\u30b3\u30fc\u304c\u5fc5\u8981\u306b\u306a\u308a\u307e\u3057\u305f(\uff1b_\uff1b)\n\u9000\u9662\u8a3a\u5bdf\u306e\u969b\u3001\u770b\u8b77\u5e2b\u3055\u3093\u306b\u6559\u308f\u3063\u305f\u306e\u3067\u3059\u304c\u3001\u53e3\u3067\u6df1\u547c\u5438\u3057\u3066\u3001\u304a\u3057\u308a\u3092\u4e0b\u306b\u3064\u3051\u308b\u3053\u3068\u304c\u3068\u3066\u3082\u5927\u4e8b\u3067\u3059")},
#         {
#             "example_id": "2666",
#             "rationale": "The example asks about a diagnosis at a hospital and whether the doctor examined the patient, but it does not specify any diagnosis or procedures.",
#             "answer": "D",
#             "quote": "\u305c\u3072\u5148\u751f\u306b\u898b\u3066\u9802\u304d\u305f\u3044\u306e\u3067\u3059\u304c\uff1f"
#         },
#         {
#             "example_id": "2667",
#             "rationale": "The text describes a person suffering from a headache and calling for help, with no mention of any diagnosis or related procedures.",
#             "answer": "D",
#             "quote": "\u30e1\u30c1\u30e3\u30af\u30c1\u30e3\u75db\u3059\u304e\u3066\u3001\u53eb\u3076\u304b\u3068\u601d\u3063\u305f\uff01"
#         }
#     ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "2749",
#             "rationale": "The text discusses HPV types and vaccination, with no mention of a specific medical diagnosis or related procedures.",
#             "answer": "D",
#             "quote": "\u65e2\u306b\u611f\u67d3\u6b74\u306e\u3042\u308bHPV\u578b\u306f\u3001\u30ef\u30af\u30c1\u30f3\u63a5\u7a2e\u3067\u306f\u4e88\u9632\u51fa\u6765\u306a\u3044\u304b\u3089"
#         },
#         {
#             "example_id": "2750",
#             "rationale": "The example mentions a "反ワクチン" (anti-vaccine) stance but does not refer to any diagnosis or procedures.",
#             "answer": "D",
#             "quote": "\u53cd\u30ef\u30af\u30c1\u30f3\u306f\u672c\u5f53\u306b\u7f6a\u6df1\u3044"
#         },
#         {
#             "example_id": "2751",
#             "rationale": "The text talks about early symptoms and pain but does not specify any diagnosis like dysplasia or cancer or related procedures.",
#             "answer": "D",
#             "quote": "\u65e9\u3044\u8a71\u3001\u4f53\u8cea\u306e\u8a71\u3067\u3059\u304b\u3089\u306d\u3047"
#         }
#     ]
# }
# ERROR json_load on: {
#   "pattern_results": [
#     {
#       "example_id": "3052",
#       "rationale": "The text discusses a medical examination related to the cervix and mentions hospital visits, but does not specify a diagnosis or procedures.",
#       "answer": "D",
#       "quote": "\u3b8\u6708\u306b\u5b50\u5bae\u9838\u304c\u3093\u306e\u691c\u67fb\u3092\u3046\u3051\u307e\u3059\u3002\n\u7121\u6599\u3067\u53d7\u3051\u308c\u308b\u30af\u30fc\u30dd\u30f3\u304c3\u6708\u672b\u307e\u3067\u3089\u3057\u304f\u3001\u75c5\u9662\u3067\u8a00\u308f\u308c\u3066\u30a4\u30e4\u30a4\u30e4\u4e88\u7d04\u3057\u307e\u3057\u305f\u304c\u3001\u4eca\u306f\u81ea\u5206\u306e\u305f\u3081\u306b\u53d7\u3051\u306b\u884c\u304d\u307e\u3059\uff01"
#     },
#     {
#       "example_id": "3053",
#       "rationale": "The text asks about the thoughts regarding a cervix condition but does not mention any diagnosis or procedures.",
#       "answer": "D",
#       "quote": "\u5b50\u5bae\u9838\u304c\u3093\u30ef\u30af\u30c1\u30f3\n\u3069\u3046\u601d\u3044\u307e\u3059\u304b\uff1f"
#     },
#     {
#       "example_id": "3054",
#       "rationale": "The text describes a procedure involving a cervical examination and a biopsy, indicating a diagnostic process related to the cervix.",
#       "answer": "A",
#       "quote": "\u3068\u308a\u3042\u3048\u305a20\u4ee3\u8d85\u3048\u3066\u3044\u305f\u3057\u3066\u305f\u3089\u5fc5\u305a\u7d19\u5c4a\u304f\u304b\u3089\u691c\u8a3a\u884c\u304d\u306a\u3055\u3044"
#     }
#   ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "3187",
#             "rationale": "The text asks if the body is healthy or not, which relates to health but not specifically a diagnosis or procedure.",
#             "answer": "D",
#             "quote": "\u4f53\u304c\u3093\u691c\u8a3a\n\u6fc0\u75db\u3067\u3059\u304b\uff1f"
#         },
#         {
#             "example_id": "3188",
#             "rationale": "The text mentions cancer ("\u6016\u3044\u3067\u3059"), which is a medical diagnosis, aligning with the pattern.",
#             "answer": "A",
#             "quote": "\u4f53\u764c\u691c\u8a3a\n\u6016\u3044\u3067\u3059"
#         },
#         {
#             "example_id": "3189",
#             "rationale": "The text discusses abnormal bleeding and cancer ("\u9838\u764c"), indicating a diagnosis, but no procedures are mentioned.",
#             "answer": "B",
#             "quote": "\u534a\u5e74\u4f4d\u4e0d\u6b63\u51fa\u8840\u304c\u3042\u308a\u3001\u9838\u764c\u3067\u306f\u306a\u304f\u3001\u4f53\u30ac\u30f3\u306a\u3063\u3066\u307e\u3057\u305f"
#         }
#     ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "3244",
#             "rationale": "The text discusses a medical examination related to the uterus but does not mention any specific diagnosis or procedures.",
#             "answer": "D",
#             "quote": "\u5b50\u5bae\u9838\u304c\u3093\u306e\u691c\u67fb\u3067\u58c1\u304b\u30893\u7b87\u6240\u3068\u308b\u691c\u67fb\u3081\u3063\u3061\u3083\u75db\u3044\u3067\u3059\u3088\u306d\uff01\uff01"
#         },
#         {
#             "example_id": "3245",
#             "rationale": "The example mentions a recent health check-up but does not specify any diagnosis or medical procedures.",
# ...
#             "quote": "\u5185\u8a3a\u3057\u3066\u304b\u3089\u306b\u3057\u307e\u3057\u3087\u3046\u3068\u8a71\u3055\u308c\u3001\u5185\u8a3a\u53f0\u306b\u3042\u304c\u3063\u3066\u304b\u3089\u3064\u3044\u3067\u306b\u5b50\u5bae\u4f53\u304c\u3093\u306e\u691c\u67fb\u3082\u3057\u3061\u3083\u3044\u307e\u3059\u306d\u3068\u3044\u304d\u306a\u308a\u3084\u3089\u308c\u75db\u3044\u306e\u3068\u5668\u5177\u3092\u5165\u308c\u308b\u6642\u9593\u3082\u9577\u304f\u3066\u3044\u308d\u3044\u308d\u3068\u91cd\u306a\u308a\u30b7\u30e7\u30c3\u30af\u3067\u610f\u8b58\u3092\u5931\u3044\u5012\u308c\u307e\u3057\u305f"},
#             {
#                 "example_id": "5099",
#                 "rationale": "The text is very brief and only mentions a general event and a large matter without any health checkup or emotional support context.",
#                 "answer": "D",
#                 "quote": "\u3048\u3063\u3061\u3083\u3093\n\u304a\u5927\u4e8b\u306b"
#             },
#             {
#                 "example_id": "5100",
#                 "rationale": "The example is a simple greeting with an emoji and does not discuss health checkups or emotional encouragement, thus not aligning with the pattern.",
#                 "answer": "D",
#                 "quote": "\u3048\u3063\u3061\u3083\u3093\n\ud83d\ude40"
#             }
#         ]
#     ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "5176",
#             "rationale": "The text discusses concerns about health irregularities and the importance of health checkups, emphasizing health awareness.",
#             "answer": "A",
#             "quote": "\u8efd\u5ea6\u306e\u7570\u5f62\u6210\u3067\u7d4c\u904e\u89b3\u5bdf\u3068\u8a00\u308f\u308c\u307e\u3057\u305f\u304c\u9032\u884c\u3057\u3066\u308b\u304b\u3087\u3057\u306c\u304b\u3089\u4eca\u5e74\u307e\u305f\u691c\u8a3a\u884c\u304d\u307e\u3059"},
#             "quote": "\u8efd\u5ea6\u306e\u7570\u5f62\u6210\u3067\u7d4c\u904e\u89b3\u5bdf\u3068\u8a00\u308f\u308c\u307e\u3057\u305f"
#         },
#         {
#             "example_id": "5177",
#             "rationale": "The example talks about health and emotional well-being, encouraging a healthy lifestyle and understanding one's feelings.",
#             "answer": "B",
#             "quote": "\u306a\u305c\u81ea\u5206\u3060\u3051\u5468\u308a\u3068\u540c\u3058\u3088\u3046\u306b\u5065\u5eb7\u3067\u3044\u3089\u308c\u306a\u3044\u306e\u304b\u3001\u65e6\u90a3\u306b\u3082\u7533\u3057\u8a33\u306a\u3044\u6c17\u6301\u3061\u3067\u3001\u6ce3\u3044\u3066\u6ce3\u3044\u3066\u6ce3\u304d\u307e\u304f\u308a\u307e\u3057\u305f"},
#             "quote": "\u540c\u3058\u7d4c\u9a13\u3092\u3055\u308c\u3066\u308b\u65b9\u306e\u8a71\u3092\u805e\u3044\u3066\u3001\u81ea\u5206\u3060\u3051\u3058\u3083\u306a\u3044\u3068\u5143\u6c17\u3092\u3082\u3089\u3048\u307e\u3057\u305f"
#         },
#         {
#             "example_id": "5178",
#             "rationale": "The example mentions the end of a relationship and expressing gratitude, but does not focus on health checkups or emotional support.",
#             "answer": "D",
#             "quote": "\u30dd\u3061\u3083\u3093\u7d42\u59cb\u304b\u308f\u3044\u3044\u2026"
#         }
#     ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "5323",
#             "rationale": "The example discusses a specific age and a question about a person, with no mention of health checkups or emotional support.",
#             "answer": "D",
#             "quote": "\u76\u4eba\u306b\uff11\u4eba\uff1f"
#         },
#         {
#             "example_id": "5324",
#             "rationale": "The text talks about checking and examining, which relates to health, but focuses more on investigation rather than emphasizing health checkups or offering support.",
#             "answer": "D",
#             "quote": "\u691c\u67fb\u306b\u884c\u304f\u3053\u3068\u3067\u3059\u306d"
#         },
#         {
#             "example_id": "5325",
#             "rationale": "The example mentions a health checkup and a medical examination, highlighting health concerns and medical procedures, aligning with the pattern's focus.",
#             "answer": "A",
#             "quote": "\u691c\u8a3a\u53d7\u3051\u3066\u3044\u3066\u826f\u304b\u3063\u305f\u3067\u3059"
#         }
#     ]
# }
# ERROR json_load on: {
#   "pattern_results": [
#     {
#       "example_id": "5347",
#       "rationale": "The text discusses health issues and symptoms, indicating concern about health conditions, which aligns with emphasizing health checkups or health awareness.",
#       "answer": "A",
#       "quote": "\u5375\u5de3\u56a2\u816b\u3068\u3044\u3046\u75c5\u6c17\u3067\u3059\u304c\u81ea\u899a\u75c7\u72b6\u304c\u306a\u3044\u4e8b\u304c\u591a\u304f\u305d\u306e\u307e\u307e\u5927\u304d\u304f\u306a\u3063\u3066\u816b\u760d\u304c\u3072\u3063\u304f\u308a\u8fd4\u3063\u305f\u308a\u7834\u88c2\u3057\u305f\u308a\u3057\u3066\u7dca\u6025\u624b\u8853\u306b\u306a\u308b\u4eba\u3082\u5c11\u306a\u304f\u306a\u3044\u3068\u805e\u3044\u3066\u305d\u3046\u306a\u308b\u524d\u306b\u898b\u3064\u3051\u308b\u3053\u3068\u304c\u51fa\u6765\u3066\u3088\u304b\u3063\u305f\u2026\u3068\u672c\u6c17\u3067\u601d\u3044\u307e\u3057\u305f"},
#       "quote": "\u5375\u5de3\u56a2\u816b\u3068\u3044\u3046\u75c5\u6c17\u3067\u3059\u304c\u81ea\u899a\u75c7\u72b6\u304c\u306a\u3044\u4e8b\u304c\u591a\u304f\u305d\u306e\u307e\u307e\u5927\u304d\u304f\u306a\u3063\u3066\u816b\u760d\u304c\u3072\u3063\u304f\u308a\u8fd4\u3063\u305f\u308a\u7834\u88c2\u3057\u305f\u308a\u3057\u3066\u7dca\u6025\u624b\u8853\u306b\u306a\u308b\u4eba\u3082\u5c11\u306a\u304f\u306a\u3044\u3068\u805e\u3044\u3066\u305d\u3046\u306a\u308b\u524d\u306b\u898b\u3064\u3051\u308b\u3053\u3068\u304c\u51fa\u6765\u3066\u3088\u304b\u3063\u305f\u2026\u3068\u672c\u6c17\u3067\u601d\u3044\u307e\u305f\u3059"}
#     },
#     {
#       "example_id": "5348",
#       "rationale": "The text talks about a standard value and a future health check, indicating a focus on health assessment rather than emotional support.",
#       "answer": "D",
#       "quote": "\u304a\u306a\u3089\u4e0d\u5b89\u3067\u3059\u3002",
#       "quote": "\u6570\u5024\u306e\u57fa\u6e96\u5024\u304c1.0\u672a\u6e80\u306a\u306e\u306b\u5bfe\u3057\u3066\u79c1\u306f2000\u8d85\u3048\u3066\u3066\u3001\u305d\u306e\u307e\u307e\u7d44\u7e54\u691c\u67fb\u3067\u4eca\u7d50\u679c\u5f85\u3061\u3067\u3059\u3002"
#     },
#     {
#       "example_id": "5349",
#       "rationale": "The example discusses health knowledge and regular checkups, which relate to health awareness but do not explicitly emphasize checkups or emotional support.",
#       "answer": "D",
#       "quote": "\u533b\u7642\u77e5\u8b58\u304c\u3042\u308b\u304b\u3089\u3053\u305d\u306e\u6016\u3055\u3082\u3042\u308b\u3088\u306d\u3001\u3001\u3001\u4f53\u5927\u4e8b\u306b\u3057\u3066\u306d\u3002",
#       "quote": "\u7570\u5e38\u304c\u306a\u304f\u3066\u3082\u5b9a\u671f\u691c\u8a3a\u7b49\u3067\u304b\u304b\u3063\u3066\u3082\u826f\u3044\u3093\u3060\u3063\u3066\u601d\u3046\u3068\u5c11\u3057\u884c\u304d\u3084\u3059\u304f\u611f\u3058\u307e\u3057\u305f\u3002"
#     }
#   ]
# }
# ERROR json_load on: {
#   "pattern_results": [
#     {
#       "example_id": "5455",
#       "rationale": "The text discusses the importance of child health and safety measures, implying a focus on health awareness and prevention.",
#       "answer": "B",
#       "quote": "\u5b50\u5bae\u9838\u304c\u3093\u306e\u4e88\u9632\u63a5\u7a2e\u6bcd\u304b\u3089\u52e7\u3081\u3089\u308c\u3066\u308b\u3093\u3067\u3051\u3069\u3001\u975e\u51e6\u5973\u306a\u306e\u30d0\u30ec\u308b\u306e\u6065\u305a\u304b\u3057\u3046\u3066\u3067\u304d\u306a\u3044"
#     },
#     {
#       "example_id": "5456",
#       "rationale": "The example emphasizes the importance of health checkups and insurance, which relates to health awareness and support.",
#       "answer": "B",
#       "quote": "\u691c\u8a3a\u306e\u524d\u306b1\u5ea6\u52a0\u5165\u3055\u308c\u3066\u3044\u308b\u4fdd\u967a\u306e\u5185\u5bb9\u78ba\u8a8d\u3092\u304a\u52e7\u3081\u3057\u307e\u3059"
#     },
#     {
#       "example_id": "5457",
#       "rationale": "The text mentions health checkups and reassurance, indicating a focus on health support and encouragement.",
#       "answer": "B",
#       "quote": "\u4eca\u306f\uff１９\u3064\u306e\u30a6\u30a4\u30eb\u30b9\u30bf\u30a4\u30d7\u306b\u5bfe\u5fdc\u3057\u3066\u3044\u308b\uff08\u4eca\u307e\u3067\u306f4\u3064\u3067\u3057\u305f\uff09"
#     }
#   ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "5473",
#             "rationale": "The example discusses receiving a health checkup and expresses gratitude, indicating a focus on health checkups and emotional support.",
#             "answer": "A",
#             "quote": "\u79c1\u3082\u6bce\u5e74\u691c\u8a3a\u3092\u53d7\u3051\u3066\u3044\u3066\u3042\u308b\u65e5\u7a81\u7136\u5f15\u3063\u304b\u304b\u308a\u307e\u3057\u305f...\n\u304d\u308a\u307e\u308b\u3061\u3083\u3093\u3060\u3063\u3066\u4e0\u5b89\u306a\u306f\u305a\u306e\u306b\u3001\u52c7\u6c17\u3082\u3089\u3044\u307e\u3057\u305f!\u3042\u308a\u304e\u3046\u3054\u3056\u3044\u307e\u3059!!"
#         },
#         {
#             "example_id": "5474",
#             "rationale": "The example mentions a family member's health and a desire to avoid certain behaviors, implying concern for health and well-being.",
#             "answer": "D",
#             "quote": "\u5b50\u5bae\u981a\u304c\u3093\u3066\u7d50\u5c40\u6027\u884c\u70ba\u3067\u306a\u308b\u304b\u3089\n\u7d76\u5bfe\u751f\u3067\u3084\u3089\u306a\u3044"
#         },
#         {
#             "example_id": "5475",
#             "rationale": "The example talks about making and caring for a younger sibling and the health of the sibling, which relates to health support and encouragement.",
#             "answer": "B",
#             "quote": "\u5b50\u5bae\u306e\u5065\u5eb7\u304c\u8d64\u3061\u3083\u3093\u306e\u5065\u5eb7\u3067\u3059\u3002"
#         }
#     ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "5584",
#             "rationale": "The text discusses recent hand surgery and expresses a feeling of curiosity, but does not mention health checkups or emotional support.",
#             "answer": "D",
#             "quote": "\u6700\u8fd1\u3053\u306e\u624b\u8853\u3057\u305f\u4eba\u306e\u8272\u3093\u306a\u4eba\u306e\u52d5\u753b\u304c\u3084\u305f\u3089\u6d41\u308c\u3066\u304f\u308b\u3093\u3060\u3051\u3069\u3002\u3002\n\u306a\u3041\u305c\u306a\u3041\u305c\uff1f"
#         },
#         {
#             "example_id": "5585",
#             "rationale": "The example describes health issues and medical examinations, indicating a focus on health concerns and support.",
#             "answer": "A",
#             "quote": "\u4e0d\u598a\u6cbb\u7642\u3067\u5a66\u4eba\u79d1\u306b\u7d042\u5e74\u901a\u3063\u3066\u305f\u3051\u3069\u8840\u304c\u6b62\u307e\u3089\u306a\u304f\u3066\u3001\u8a3a\u3066\u3082\u3089\u3063\u3066\u7b4b\u816b\u304c\u3042\u3063\u3066\u3001\u53d6\u3063\u3066\u3082\u3089\u3063\u3066\u691c\u67fb\u306b\u56de\u3057\u305f\u6240\u60aa\u6027\u3067\u3057\u305f\u5b50\u5bae\u4f53\u764c\u3067\u3057\u305f\u3002\n\u521d\u671f\u3067\u826f\u304b\u3063\u305f\u3088\u3068\u5148\u751f\u3082\u8a00\u3063\u3066\u307e\u3057\u305f\u304c\u3001\uCT\u3068 MRI\u3067\u5f15\u3063\u304b\u304b\u3089\u306a\u3044\u304b\u4e0d\u5b89\u3067\u3057\u3087\u304c\u304a\u3069\u3046\u304b\u3044\u306a\u3044\u3067\u3059\ud83d\udca6"
#         },
#         {
#             "example_id": "5586",
#             "rationale": "The text talks about physical strength and illness, but does not emphasize health checkups or emotional support.",
#             "answer": "D",
#             "quote": "\u3072\u305f\u3059\u3089\u529b\u629c\u3044\u3066\u6df1\u547c\u5438\u306b\u96c6\u4e2d\u3057\u3088\u3046\u306d\uff01"
#         }
#     ]
# }
# ERROR json_load on: {
#   "pattern_results": [
#     {
#       "example_id": "5617",
#       "rationale": "The text discusses a past health checkup and expresses a desire to have a checkup again, emphasizing the importance of health monitoring.",
#       "answer": "A",
#       "quote": "\u672c\u5f53\u306b\u30b7\u30e7\u30c3\u30af\u3067\u843d\u3061\u8fbc\u307f\u307e\u3057\u305f\u3002"
#     },
#     {
#       "example_id": "5618",
#       "rationale": "The example mentions a health diagnosis and the importance of health checks, along with encouragement to get checked, highlighting health awareness.",
#       "answer": "A",
#       "quote": "\u81ea\u5206\u306e\u8eab\u4f53\u306e\u305f\u3081\u306b\u3082\u6c17\u306b\u306a\u3063\u305f\u3089\u53d7\u8a3a\u3092\u3059\u308b\u306e\u304c\u5927\u4e8b\u306a\u3093\u3060\u3068\u5b9f\u611f\u3057\u307e\u3057\u305f\u3002"
#     },
#     {
#       "example_id": "5619",
#       "rationale": "The text describes a recent health diagnosis and the importance of regular checkups, encouraging health awareness.",
#       "answer": "A",
#       "quote": "\u4eca\u65e5\u5065\u5eb7\u8a3a\u65ad\u304c\u3042\u3063\u305f\u306e\u3067\u3001\u4eca\u65e5\u4e00\u7dd2\u306b\u3084\u3089\u306a\u3044\u3068\u4e00\u751f\u3084\u3089\u306a\u3044\u6c17\u304c\u3057\u305f\u306e\u3067\u3064\u3044\u306b\u691c\u8a3a\u3057\u3066\u304d\u307e\u3057\u305f\uff01\uff"
#     }
#   ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "5668",
#             "rationale": "The example discusses a health checkup and its results, emphasizing the importance of health monitoring.",
#             "answer": "A",
#             "quote": "\u6614\u3001\u9838\u304c\u3093\u691c\u67fb\u3067\u8efd\u5ea6\u7570\u5f62\u6210\u304c\u898b\u3064\u304b\u3063\u305f\u306e\u3067\u30b3\u30eb\u30dd\u8a3a\u53d7\u3051\u307e\u3057\u305f\uff01"
#         },
#         {
#             "example_id": "5669",
#             "rationale": "The example mentions feeling good about health and being regularly checked, which relates to health awareness and support.",
#             "answer": "B",
#             "quote": "\u79c1\u308226\u6b73\u3067\u8efd\u5ea6\u7570\u5f62\u6210\u3042\u3063\u3066\u5b9a\u671f\u7684\u306b\u75c5\u9662\u901a\u3063\u3066\u308b\u3088\u3002"
#         },
#         {
#             "example_id": "5670",
#             "rationale": "The example reflects on past health issues and ongoing health concerns, highlighting the importance of health monitoring.",
#             "answer": "A",
#             "quote": "\u305d\u308c\u304b\u3089\u5b50\u5bae\u4f53\u304c\u3093\u3082\uff１１\u5e74\u3001\uff１２\u5e74\u306b\u3044\u3061\u3069\u53d7\u3051\u3066\u307e\u3059\u3002"
#         }
#     ]
# }
# ERROR json_load on: {
#     "pattern_results": [
#         {
#             "example_id": "5677",
#             "rationale": "The example discusses feelings about men's behavior and infection routes without mentioning health checkups or emotional support.",
#             "answer": "D",
#             "quote": "\u3082\u3063\u3068\u7537\u6027\u304c\u6253\u3064\u3079\u304d\u3063\u3066\u8a00\u3063\u3066\u307b\u3057\u3044\u3093\u3060\u3051\u3069\n\u611f\u67d3\u7d4c\u8def\u306f\u307b\u307c\u307b\u307c\u6027\u884c\u70ba\u3067\u306e\u7537\u304b\u3089\u5973\u3063\u3066\u5206\u304b\u3063\u3066\u308b\u306e\u306b\u306a\u3093\u3067\u8a00\u308f\u306a\u3044\u306e\uff1f\u96a0\u3057\u3066\u308b\uff1f"
#         },
#         {
#             "example_id": "5678",
#             "rationale": "The text mentions HPV and health but does not focus on health checkups or emotional support; it describes health issues.",
#             "answer": "D",
#             "quote": "\u5b50\u5bae\u5f31\u304f\u3066\u60aa\u6027\u306eHPV\u304c\u967d\u6027\n\u764c\u306b\u306a\u3063\u3061\u3083\u3046\u304b\u3082"
#         },
#         {
#             "example_id": "5679",
#             "rationale": "The example states "\u3088\u3046\u306f\u6027\u75c5" which indicates a mention of a sexual disease but does not emphasize health checkups or emotional support.",
#             "answer": "D",
#             "quote": "\u3088\u3046\u306f\u6027\u75c5"
#         }
#     ]
# }
# ✓ Completed concept: Health and Support
# ✅ Done with concept scoring!

# %%
if 'score_df' in locals():
  # スコア結果が既にある場合
  score_df.to_csv("lloom_scores_latest.csv", index=False,
encoding="utf-8-sig")
  print("保存完了: lloom_scores_latest.csv")
else:
  print("まずスコアリングを完了してください")
# Out:
# 保存完了: lloom_scores_latest.csv

# %%
score_df
# Out:
#      doc_id                                               text  \
# 0         0  \u5973\u6027\u82e5\u3044\u30a2\u30e9\u30b5\u30...
# 1         1  \u3053\u3093\u3070\u3093\u306f\n\u82e5\u3044\u...
# 2         2       \u5973\u6027\u60a3\u8005\n\u5b50\u5bae\u981a
# 3         3  \u5b50\u5bae\u3051\u3044\u304c\u3093\u306f\n\u...
# 4         4  \u5b50\u5bae\u75d9\u304b\u3093\n\u5973\u6027\u...
# ...     ...                                                ...
# 5694   4098  \u598a\u6d3b\u59cb\u3081\u305f\u3068\u3057\u30...
# 5695   4271  \u79c1\u3082\u5b50\u5bae\u4f53\u764c\u3067\u5b...
# 5696   4272  \u6bce\u56de\u3001PET\u691c\u67fb\u306e\u3001\...
# 5697   5093  \u9ad8\u5ea6\u7570\u5f62\u6210\u306e\u6b21\u30...
# 5698   5094  \u3060\u304b\u3089\u5973\u6027\u306e\u7686\u30...
#
#                                concept1_id      concept1_name  \
# 0     5711b6ed-83b3-45dc-a1c5-4567cd6c903b  Medical Diagnosis
# 1     5711b6ed-83b3-45dc-a1c5-4567cd6c903b  Medical Diagnosis
# 2     5711b6ed-83b3-45dc-a1c5-4567cd6c903b  Medical Diagnosis
# 3     5711b6ed-83b3-45dc-a1c5-4567cd6c903b  Medical Diagnosis
# 4     5711b6ed-83b3-45dc-a1c5-4567cd6c903b  Medical Diagnosis
# ...                                    ...                ...
# 5694  5711b6ed-83b3-45dc-a1c5-4567cd6c903b  Medical Diagnosis
# 5695  5711b6ed-83b3-45dc-a1c5-4567cd6c903b  Medical Diagnosis
# 5696  5711b6ed-83b3-45dc-a1c5-4567cd6c903b  Medical Diagnosis
# 5697  5711b6ed-83b3-45dc-a1c5-4567cd6c903b  Medical Diagnosis
# 5698  5711b6ed-83b3-45dc-a1c5-4567cd6c903b  Medical Diagnosis
#
#                                         concept1_prompt  concept1_score  \
# 0     Does the text mention a medical diagnosis, suc...            0.25
# 1     Does the text mention a medical diagnosis, suc...            0.25
# 2     Does the text mention a medical diagnosis, suc...            0.25
# 3     Does the text mention a medical diagnosis, suc...            0.25
# 4     Does the text mention a medical diagnosis, suc...            0.25
# ...                                                 ...             ...
# 5694  Does the text mention a medical diagnosis, suc...            0.00
# 5695  Does the text mention a medical diagnosis, suc...            0.00
# 5696  Does the text mention a medical diagnosis, suc...            0.00
# 5697  Does the text mention a medical diagnosis, suc...            0.00
# 5698  Does the text mention a medical diagnosis, suc...            0.00
#
#                                      concept1_rationale  \
# 0     The text mentions a disease related to women a...
# 1     The text describes age and gender but does not...
# 2     The text mentions a disease and a location but...
# 3     The example mentions a medical facility and a ...
# 4     The example references a woman patient and a c...
# ...                                                 ...
# 5694
# 5695
# 5696
# 5697
# 5698
#
#                                      concept1_highlight  concept1_seed  \
# 0     \u5973\u6027\u82e5\u3044\u30a2\u30e9\u30b5\u30...            NaN
# 1     \u3053\u3093\u3070\u3093\u306f\n\u82e5\u3044\u...            NaN
# 2          \u5973\u6027\u60a3\u8005\n\u5b50\u5bae\u981a            NaN
# 3     \u5b50\u5bae\u3051\u3044\u304c\u3093\u306f\n\u...            NaN
# 4     \u5b50\u5bae\u75d9\u304b\u3093\n\u5973\u6027\u...            NaN
# ...                                                 ...            ...
# 5694                                                               NaN
# 5695                                                               NaN
# 5696                                                               NaN
# 5697                                                               NaN
# 5698                                                               NaN
#
#                                concept2_id  ...  \
# 0     644481e1-85f4-4ccd-91ee-e0170e4872fd  ...
# 1     644481e1-85f4-4ccd-91ee-e0170e4872fd  ...
# 2     644481e1-85f4-4ccd-91ee-e0170e4872fd  ...
# 3     644481e1-85f4-4ccd-91ee-e0170e4872fd  ...
# 4     644481e1-85f4-4ccd-91ee-e0170e4872fd  ...
# ...                                    ...  ...
# 5694  644481e1-85f4-4ccd-91ee-e0170e4872fd  ...
# 5695  644481e1-85f4-4ccd-91ee-e0170e4872fd  ...
# 5696  644481e1-85f4-4ccd-91ee-e0170e4872fd  ...
# 5697  644481e1-85f4-4ccd-91ee-e0170e4872fd  ...
# 5698  644481e1-85f4-4ccd-91ee-e0170e4872fd  ...
#
#                                      concept5_rationale  \
# 0     The example discusses a female patient and her...
# 1     The example mentions a young woman and her age...
# 2     The example states 'female patient' and 'child...
# 3     The example discusses a career change and work...
# 4     The example mentions a woman patient and infor...
# ...                                                 ...
# 5694  The text describes a personal activity related...
# 5695  The example describes personal health issues a...
# 5696  The text discusses medical testing and results...
# 5697  The example talks about concerns with high irr...
# 5698  The text mentions women wanting to get checked...
#
#                                      concept5_highlight  concept5_seed  \
# 0     \u5973\u6027\u82e5\u3044\u30a2\u30e9\u30b5\u30...            NaN
# 1     \u82e5\u3044\u5973\u6027\u306f\u4e8c\u5341\u6b...            NaN
# 2          \u5973\u6027\u60a3\u8005\n\u5b50\u5bae\u981a            NaN
# 3     \u5b50\u5bae\u3051\u3044\u304c\u3093\u306f\n\u...            NaN
# 4     \u5b50\u5bae\u75d9\u304b\u3093\n\u5973\u6027\u...            NaN
# ...                                                 ...            ...
# 5694  \u598a\u6d3b\u59cb\u3081\u305f\u3068\u3057\u30...            NaN
# 5695  \u79c1\u3082\u5b50\u5bae\u4f53\u764c\u3067\u5b...            NaN
# 5696  \u6bce\u56de\u3001PET\u691c\u67fb\u306e\u3001\...            NaN
# 5697  \u9ad8\u5ea6\u7570\u5f62\u6210\u306e\u6b21\u30...            NaN
# 5698  \u3060\u304b\u3089\u5973\u6027\u306e\u7686\u30...            NaN
#
#                                concept6_id       concept6_name  \
# 0     92ab2c05-358b-4fb7-8a69-65b106a057ab  Health and Support
# 1     92ab2c05-358b-4fb7-8a69-65b106a057ab  Health and Support
# 2     92ab2c05-358b-4fb7-8a69-65b106a057ab  Health and Support
# 3     92ab2c05-358b-4fb7-8a69-65b106a057ab  Health and Support
# 4     92ab2c05-358b-4fb7-8a69-65b106a057ab  Health and Support
# ...                                    ...                 ...
# 5694  92ab2c05-358b-4fb7-8a69-65b106a057ab  Health and Support
# 5695  92ab2c05-358b-4fb7-8a69-65b106a057ab  Health and Support
# 5696  92ab2c05-358b-4fb7-8a69-65b106a057ab  Health and Support
# 5697  92ab2c05-358b-4fb7-8a69-65b106a057ab  Health and Support
# 5698  92ab2c05-358b-4fb7-8a69-65b106a057ab  Health and Support
#
#                                         concept6_prompt concept6_score  \
# 0     Does the text emphasize the importance of heal...           1.00
# 1     Does the text emphasize the importance of heal...           1.00
# 2     Does the text emphasize the importance of heal...           1.00
# 3     Does the text emphasize the importance of heal...           1.00
# 4     Does the text emphasize the importance of heal...           1.00
# ...                                                 ...            ...
# 5694  Does the text emphasize the importance of heal...           0.00
# 5695  Does the text emphasize the importance of heal...           0.75
# 5696  Does the text emphasize the importance of heal...           0.25
# 5697  Does the text emphasize the importance of heal...           1.00
# 5698  Does the text emphasize the importance of heal...           1.00
#
#                                      concept6_rationale  \
# 0     The example mentions a female patient and a pe...
# 1     The text discusses a young woman and a pediatr...
# 2     The phrase 'female patient' and 'pediatrician'...
# 3     The example mentions a health checkup and a pr...
# 4     The example discusses a health checkup and men...
# ...                                                 ...
# 5694
# 5695  The example mentions sharing health informatio...
# 5696  The text discusses the results of medical exam...
# 5697  The example mentions concerns about health iss...
# 5698  The text talks about women wanting health chec...
#
#                                      concept6_highlight  concept6_seed
# 0     \u5973\u6027\u82e5\u3044\u30a2\u30e9\u30b5\u30...            NaN
# 1     \u82e5\u3044\u5973\u6027\u306f\u4e8c\u5341\u6b...            NaN
# 2          \u5973\u6027\u60a3\u8005\n\u5b50\u5bae\u981a            NaN
# 3     \u5b50\u5bae\u3051\u3044\u304c\u3093\u306f\n\u...            NaN
# 4     \u5b50\u5bae\u75d9\u304b\u3093\n\u5973\u6027\u...            NaN
# ...                                                 ...            ...
# 5694                                                               NaN
# 5695  \u79c1\u3082\u5b50\u5bae\u4f53\u764c\u3067\u5b...            NaN
# 5696  \u6bce\u56de\u3001PET\u691c\u67fb\u306e\u3001\...            NaN
# 5697  \u9ad8\u5ea6\u7570\u5f62\u6210\u306e\u6b21\u30...            NaN
# 5698  \u81ea\u5206\u306e\u4f53\u3092\u5b88\u308c\u30...            NaN
#
# [5699 rows x 44 columns]

# %%
l.summary()
# Out:
# Total time: 4145.82 sec (69.10 min)
# 	('Distill-filter', '2025-07-31-13-50-06'): 185.94 sec
# 	('Distill-summarize', '2025-07-31-13-53-11'): 184.97 sec
# 	('Cluster', '2025-07-31-13-54-22'): 70.61 sec
# 	('Synthesize', '2025-07-31-13-54-50'): 28.01 sec
# 	('Review-remove', '2025-07-31-13-54-52'): 2.61 sec
# 	('Review-merge', '2025-07-31-13-54-55'): 3.02 sec
# 	('Score', '2025-07-31-15-20-41'): 3670.66 sec
#
#
# Total cost: $5.59
# 	('Distill-filter', '2025-07-31-13-50-06'): $0.870
# 	('Distill-summarize', '2025-07-31-13-53-11'): $0.631
# 	('Synthesize', '2025-07-31-13-54-50'): $1.188
# 	('Review-remove', '2025-07-31-13-54-52'): $0.002
# 	('Review-merge', '2025-07-31-13-54-55'): $0.004
# 	('Score-helper', '2025-07-31-14-25-42'): $0.466
# 	('Score-helper', '2025-07-31-14-38-38'): $0.525
# 	('Score-helper', '2025-07-31-14-45-56'): $0.459
# 	('Score-helper', '2025-07-31-15-01-14'): $0.507
# 	('Score-helper', '2025-07-31-15-12-52'): $0.472
# 	('Score-helper', '2025-07-31-15-20-40'): $0.463
#
#
# Tokens: total=16278968, in=10731101, out=5547867

# %%
from text_lloom.src.text_lloom.llm import OpenAIModel, OpenAIEmbedModel
# API keyを確認
api_key = os.environ.get("OPENAI_API_KEY")
# モデルを再設定
l.distill_model = OpenAIModel(name="gpt-4.1-mini",api_key=api_key)
l.cluster_model =OpenAIEmbedModel(name="text-embedding-3-large", api_key=api_key)
l.synth_model = OpenAIModel(name="gpt-4.1-mini", api_key=api_key)
l.score_model = OpenAIModel(name="gpt-4.1-nano",api_key=api_key)

print("モデル再設定完了")
# Out:
# モデル再設定完了
